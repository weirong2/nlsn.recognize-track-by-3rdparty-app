# %% [markdown]
# # SW Preparation
# ### ADB tool
# * [Download the ADB zip file for Windows](https://dl.google.com/android/repository/platform-tools-latest-windows.zip)
# * Extract the contents of this ZIP file into an easily accessible folder (such as C:\android\platform-tools)
# * Connect your android phone / tablet and open command prompt to test if adb is working, detail commands can refer this [article](https://www.howtogeek.com/125769/how-to-install-and-use-abd-the-android-debug-bridge-utility/)
# ```
# C:\Users\rowe8002\AppData\Local\Android\Sdk\platform-tools>adb devices
# List of devices attached
# QMKNW17321007584        device
# ```
# * Add adb executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### OCR tool
# * [Download tesseract Windows binary](https://github.com/tesseract-ocr/tesseract/wiki/Downloads)
# * Install it as its installer instructed
# * Open command prompt to verify the install
# ```
# C:\Users\rowe8002>tesseract --version
# tesseract 3.05.02
#  leptonica-1.75.3
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.3) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.2.0
# ```
# * Add tessract executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### Python package
# * We recommand anacond3 for python package
#     * run **conda search \[packagename\]** to find the package and **conda install \[packagename\]** to install it.
#     * In case the package doesn't in anaconda repository, run **pip search \[packagename\]** to find the package and **pip install \[packagename\]** to install it
# * **PIL / threading / keyboard / os / pyaudio / subprocess / time / wave** are the packages required for this program
#
# ### Third party music recognition APP
# * QQ music (this program was initally written for QQ music)
#
# # HW Preparation
# * android phone (or tablet)
# * usb cable for PC and andriod device connection
#
# # Notes
# * below code is adjust to adapt 1200x1920 screen size tablet, if you use a different screen size android device, you need to update image crop postion & adb input tap postion accordingly.
# * I would recommand to use big screen device like tablet to run the test, as the track title maybe displayed to 3+ lines if using small screen device, which increase the inaccuracy of ocr.
#
# *Any question please contact wei.rong@nielsen.com*

# %% [markdown]
# Switch to recognition screen and start the script
# <img src="guide.png">

# %%
#!usr/bin/env python  
#coding=utf-8  

from PIL import Image
from threading import Thread
import getopt, keyboard, os, pyaudio
import subprocess, sys, time, wave

# %%
########functions for wav playing########
def _wp_init(f):
    p = pyaudio.PyAudio()  
    #open stream  
    stream = p.open(format = p.get_format_from_width(f.getsampwidth()),  
                channels = f.getnchannels(),  
                rate = f.getframerate(),  
                output = True)
    return p, stream

def _wp_run(f,c,s):
    data = f.readframes(c)
    while data:
        if keyboard.is_pressed('q'): break
        s.write(data)
        data = f.readframes(c)

def _wp_deInit(s,p,f):
    s.stop_stream()  
    s.close()
    f.close()
    p.terminate()

def wavPlaying(file):
    chunk = 1024
    wavfile = wave.open(file,"rb")  
    p, stream = _wp_init(wavfile)
    _wp_run(wavfile,chunk,stream)
    _wp_deInit(stream,p,wavfile)    

########functions for image crop########
def _im_crop_save(src,des,box):
    img = Image.open(src+".png")
    img2 = img.crop(box)
    img2.save(des+".png")

def _im_add_suffix(src,suffix):
    if os.path.isfile(src+'.png'):
        os.rename(src+'.png',src+'_'+suffix+'.png')
    
def _im_cleanup(name):
    for i in range(3):
        for j in ['png','txt']:
            f = name+'_check0'+str(i+1)+'.'+j
            try:
                os.remove(f)
            except OSError as e:
                #print(e)
                pass

def _im_cleanup_extracted_string(s):
    if s[:4] == '_ 一 ' and s[-4:] == ' 一 _': s = s[4:-4]
    if s[:2] == '一 ' and s[-2:] == ' 一': s = s[2:-2]
    if s[:2] == '— ' and s[-2:] == ' —': s = s[2:-2]
    if s[:2] == '一 ' and s[-2:] == ' —': s = s[2:-2]
    if s[:2] == '— ' and s[-2:] == ' 一': s = s[2:-2]
    if s[:2] == '一 ' and s[-1:] == '_': s = s[2:-1]
    if s[:1] == '_' and s[-1:] == '_': s = s[1:-1]
    return s.strip()
    
def _im_extract_track_artist(src):
    ret, error, track1, track2, artist = True, [], '', '', ''

    _im_crop_save(src, src+"_matchup_track", (120, 1255, 1080, 1365))
    
    track1 = _ocr_to_string(src+"_matchup_track")
    track1 = _im_cleanup_extracted_string(track1)
    if not len(track1): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL')

    #try with psm7 as single line 
    track2 = _ocr_to_string(src+"_matchup_track",False,'-l chi_sim+eng -psm 7')
    track2 = _im_cleanup_extracted_string(track2)
    if not len(track2): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_PSM7_FAIL')

    _im_crop_save(src, src+"_matchup_artist", (120, 1365, 1080, 1405))
    artist = _ocr_to_string(src+"_matchup_artist",False,'-l chi_sim+eng -psm 7')
    artist = _im_cleanup_extracted_string(artist)
    if not len(artist): error.append('SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL')

    if error == []: error.append('SCREEN_MATCHUP_EXTRACT_DONE')

    return ret, '|'.join(error), track1, track2, artist

########functions for image ocr########
def _ocr_to_string(img, cleanup=False, plus='-l chi_sim+eng'):
    subprocess.check_output('tesseract '+img+'.png'+' '+img+' '+plus, shell=True)
    text = ''
    with open(img + '.txt', 'r', encoding='UTF-8') as f:
        text = f.read().strip().replace('\n',' ')
    if cleanup:
        os.remove(img + '.txt')
    return text

########functions for android manipulation########
def _am_formatDuration(d):
    mins = d//60;
    secs = d - mins*60
    return "%02dm%02ds"%(mins,secs)

def _am_getDevices():
    cmd = "adb devices"
    out = subprocess.check_output(cmd.split())
    list = out.decode('utf-8').strip().split('\r\n')
    #print(list)
    return list

def _am_init():
    devices = _am_getDevices()
    if len(devices) <= 1 or '\tdevice' not in devices[-1]:
        cmd = "adb kill-server"
        out = subprocess.check_output(cmd.split())
        time.sleep(5)
        cmd = "adb start-server"
        out = subprocess.check_output(cmd.split())
        list = out.decode('utf-8').strip().split('\r\n')
        print(list)
        if 'successfully' not in list[-1]: return False
    return True

def _am_getScreenSize(st):
    print("%s:_am_getScreenSize " % _am_formatDuration(int(time.time()-st)),end='')
    cmd = "adb shell wm size"
    out = subprocess.check_output(cmd.split())
    size = tuple((out.decode('utf-8').strip().split('\r\n')[0].split(' ')[2].split('x')))
    print(size)
    return size

def _am_launchApp(st):
    print("%s:_am_launchApp" % _am_formatDuration(int(time.time()-st)))

def _am_CaptureFullScreen(des):
    cmd = "adb shell screencap -p /sdcard/screencap.png"
    out = subprocess.check_output(cmd.split())
    cmd = "adb pull /sdcard/screencap.png %s%s" % (des,".png")
    out = subprocess.check_output(cmd.split())
    if 'pulled' not in out.decode('utf-8').strip():
        print("%s:screencap or pull failed, exit..." % _am_formatDuration(int(time.time()-st)))
        return False, "SCREENCAP_OR_PULL_FAILED"
    return True, "SCREENCAP_AND_PULL_DONE"

def _am_pressRecognition():
    cmd = "adb shell input tap 300 1715"        #this is recognition icon position
    out = subprocess.check_output(cmd.split())

def _am_pressRetry():
    cmd = "adb shell input tap 600 1530"        #this is re-try buttom
    out = subprocess.check_output(cmd.split())

def _am_pressBack():
    cmd = "adb shell input tap 40 90"           #this is back arrow position
    out = subprocess.check_output(cmd.split())

def _am_onScreenAction(fn,out,ss,pos,rc):
    tsvFile = open(os.path.join(out,fn)+'.tsv','a')
    
    formatPos = _am_formatDuration(pos)
    print("%s\t"%formatPos, end='')
    
    ret, err = True, 'SCREEN_UNKNOWN'

    #caputre the full sceen
    name = os.path.join(out,"%s_%s" % (fn,pos))
    ret, err = _am_CaptureFullScreen(name)
    if not ret: return ret,err

    #crop to have multiple check-point sub-images to identify screen
    _im_crop_save(name, name+"_check01", (0, 180, 1200, 240))   #匹配到以下结果
    _im_crop_save(name, name+"_check02", (0, 610, 1200, 675))   #请求超时/未匹配到结果/无网络连接
    _im_crop_save(name, name+"_check03", (0, 1505, 1200, 1555)) #重试/停止识别/开始识别/重新识别/查看识别历史

    if '匹配到以下结果' in _ocr_to_string(name+"_check01"):
        if rc == 0: #if first round screen is match_up, skip it as it may be presenting the previous track meta
            print("SCREEN_SKIP_FIRST_MATCHUP",end='')
            _im_add_suffix(name,'skip')
            ret, err =  True, 'SCREEN_SKIP_FIRST_MATCHUP'
            tsvFile.write("%s\t\t\t"%pos)
        else:
            ret, err, track1, track2, artist = _im_extract_track_artist(name)
            print("%s\t%s\t%s\t%s"%(err,track1,track2,artist),end='')
            tsvFile.write("%s\t%s\t%s\t%s"%(pos,track1,track2,artist))
            _im_add_suffix(name,'matchup')
        _am_pressBack()
        _am_pressRecognition()
    elif '停止识别' in _ocr_to_string(name+"_check03"):
        print("SCREEN_MATCHING",end='')
        _im_add_suffix(name,'matching')
        ret, err =  True, 'SCREEN_MATCHING'
        tsvFile.write("%s\t\t\t"%pos)
    else:
        check02str = _ocr_to_string(name+"_check02")
        if '未匹配到结果' in check02str:
            print("SCREEN_NO_MATCH",end='')
            _im_add_suffix(name,'nomatch')
            ret, err =  True, 'SCREEN_NO_MATCH'
            _am_pressBack()
        elif '请求超时' in check02str:
            print("SCREEN_REQ_TIMEOUT",end='')
            _im_add_suffix(name,'timeout')
            ret, err =  True, 'SCREEN_REQ_TIMEOUT'
            _am_pressRetry()
        elif '发生错误了' in check02str:
            print("SCREEN_ERROR_OCCUR",end='')
            _im_add_suffix(name,'errOccur')
            ret, err =  True, 'SCREEN_ERROR_OCCUR'
            _am_pressBack()
        else:
            print("SCREEN_UNKNOWN",end='')
            _im_add_suffix(name,'unkown')
            ret, err = True, 'SCREEN_UNKNOWN'
            _am_pressBack()
        tsvFile.write("%s\t\t\t"%pos)
        _am_pressRecognition
    
    _im_cleanup(name)
    print('\n',end='')
    tsvFile.write('\n')
    tsvFile.close()
    return ret, err

def androidManipulation(t,inF,outD,screenSize,interval):
    roundCount = 0 #in case the match up screen is presenting previous recognized track

    startTime = time.time()
    while t.isAlive():
        pos = int(time.time()-startTime)
        if (pos % interval) == 0:
            ret,errorInfo = _am_onScreenAction(inF,outD,screenSize,pos,roundCount)
            roundCount = roundCount + 1
            if not ret:
                print(errorInfo)
                break

########wav play & android manipulation threads########
def simuThreads(inF,outD,screenSize,interval):
    threadWp = Thread(target=wavPlaying, args=(inF,))
    threadWp.start()

    threadAm = Thread(target=androidManipulation, args=(threadWp,os.path.basename(inF),outD,screenSize,interval,))
    threadAm.start()

    threadWp.join()
    threadAm.join()

# %%
def usage():
    print("Usage:")
    print("python simulation_qqmusic.py --wav_dir=$wavDir --out_dir=$outDir --interval=$interval")
    print("  $wav_dir: the input directory for wave files")
    print("  $out_dir: the output directory for result tsv file and corresponding images")
    print("  $interval: optional, the interval (in second) to check screen content, default is 60 seconds")
    exit()

def main(argv):
    opts, args = getopt.getopt(argv[1:], "h", ['wav_dir=', 'out_dir=', 'interval='])

    wavDir,outDir,interval = '','',60

    for o, a in opts:
        if o in ('-h'):
            usage()
        elif o in ('--wav_dir'):
            wavDir = a
        elif o in ('--out_dir'):
            outDir = a
        elif o in ('--interval'):
            interval = a

    if wavDir == '' or outDir == '':
        print("missing parameter, please check usage.")
        usage()

    try:
        int(interval)
    except ValueError:
        print("invalid interval, please check usage.")
        usage()

    print("wav files directory is : %s"%wavDir)
    print("   output directory is : %s"%outDir)
    print("           interval is : %s seconds"%interval)
    
    if not os.path.isdir(wavDir):
        print("wav directory %s does NOT exist, exit...")
        exit()

    fileList = os.listdir(wavDir)
    wavList = []
    for i in fileList:
        ext = os.path.splitext(os.path.basename(i))[1]
        if '.wav' == ext:
            wavList.append(i)

    if os.path.isdir(outDir): os.rename(outDir,outDir+'_'+time.strftime('%Y%m%d_%H%M%S',time.localtime()))
    os.makedirs(outDir, exist_ok=True)

    #init andriod device
    if not _am_init():
        print("android manipulation exit due to adb init failure...")
        return
    
    #get screen size. TODO: pass screenSize as parameter for tap & crop
    #screenSize = _am_getScreenSize(startTime)
    #_am_launchApp(startTime)
    screenSize = ('1200', '1920')
    
    totalCount = 0
    for i in sorted(wavList):
        totalCount = totalCount + 1
        print("[%03d:\t%s]"%(totalCount,i))
        simuThreads(os.path.join(wavDir,i),outDir,screenSize,int(interval))

# %%
#sys.argv = ['simulation_qqmusic.py', '--wav_dir', 'wav_folder_test', '--out_dir', '_out_test', '--interval', '45']
#sys.argv = ['simulation_qqmusic.py', '--wav_dir', '_archive\wav_folder_test', '--out_dir', '_out_xxx']
sys.argv = ['simulation_qqmusic.py', '--wav_dir', 'wav_pool_0725-29', '--out_dir', '_out_wav_pool_0725-29']

##########Main()##########
if __name__ == '__main__':
    main(sys.argv)
# Out:
# wav files directory is : wav_pool_0725-29
#    output directory is : _out_wav_pool_0725-29
#            interval is : 60 seconds
# [001:	20180725001101.wav_sub_1541_1741_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	空舞	空舞	昊青峰/陈粒
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	空舞	空舞	昊青峰/陈粒
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	空舞	空舞	昊青峰/陈粒
# [002:	20180725001101.wav_sub_713_1021_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	曙色	曙色
# 03m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	曙色	曙色
# 04m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	曙色	曙色
# [003:	20180725021101.wav_sub_2252_2494_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		读你	陈淑桦/李宗盛
# 02m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		读你	陈淑桦/李宗盛
# 03m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		读你	陈淑桦/李宗盛
# [004:	20180725061100.wav_sub_1942_2172_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# [005:	20180725071101.wav_sub_1471_1725_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# [006:	20180725071101.wav_sub_1471_1725_0072.wav]
# 00m00s	SCREEN_NO_MATCH
# [007:	20180725071101.wav_sub_1717_2031_0102.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Bad To The Bone (Extended Mix)	Bad To The Bone (Extended Mix)	Olly James/ZZBullets
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [008:	20180725071101.wav_sub_214_630_0000.wav]
# 00m00s	SCREEN_MATCHING
# [009:	20180725071101.wav_sub_2576_2776_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# [010:	20180725071101.wav_sub_796_1068_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	那年的愿望	那年的愿望	好妹妹
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	那年的愿望	那年的愿望	好妹妹
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	那年的愿望	那年的愿望	好妹妹
# [011:	20180725081101.wav_sub_2561_2785_0006.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	月 壳看我	月 壳看我	王庆爽
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	月 壳看我	月 壳看我	王庆爽
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	月 壳看我	月 壳看我	王庆爽
# [012:	20180725081101.wav_sub_827_1441_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Moon River	Moon River	新爱乐交响乐团
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Messe: Cum Jubilo: Agnus Dei	Messe: Cum Jubilo: Agnus Dei	The Gentlemen of Durham CathedraI/James Lancelot/Keith Wright
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Moon River	Moon River	新爱乐交响乐团
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Moon River	Moon River	新爱乐交响乐团
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	Just YOU Wait	Just YOU Wait	新爱乐交响乐团
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	Just YOU Wait	Just YOU Wait	新爱乐交响乐团
# 07m00s	SCREEN_MATCHUP_EXTRACT_DONE	Just YOU Wait	Just YOU Wait	新爱乐交响乐团
# 08m00s	SCREEN_MATCHUP_EXTRACT_DONE	Over The Rainbow	Over The Rainbow	新爱乐交响乐团
# 09m00s	SCREEN_MATCHUP_EXTRACT_DONE	Over The Rainbow	Over The Rainbow	新爱乐交响乐团
# 10m00s	SCREEN_MATCHUP_EXTRACT_DONE	Over The Rainbow	Over The Rainbow	新爱乐交响乐团
# [013:	20180725111101.wav_sub_2971_3219_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	相思河 畔	相思河 畔	刘文正
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	相思河 畔	相思河 畔	刘文正
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	相思河 畔	相思河 畔	刘文正
# [014:	20180725141101.wav_sub_1958_2170_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		花	杭盖乐队
# 02m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		花	杭盖乐队
# [015:	20180725141101.wav_sub_932_1366_0318.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	剪羊毛	剪羊毛	亚洲天使童声合唱团
# [016:	20180725151101.wav_sub_671_1021_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	心中的故乡	心中的故乡	蒋大为
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	心中的故乡	心中的故乡	蒋大为
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	心中的故乡	心中的故乡	蒋大为
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	心中的故乡	心中的故乡	蒋大为
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	心中的故乡	心中的故乡	蒋大为
# [017:	20180725171101.wav_sub_2156_2386_0006.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Take Me Home′ Country Roads (Live)	Take Me Home′ Country Roads (Live)	塔斯肯
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Take Me Home′ Country Roads (Live)	Take Me Home′ Country Roads (Live)	塔斯肯
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Take Me Home′ Country Roads (Live)	Take Me Home′ Country Roads (Live)	塔斯肯
# [018:	20180725191101.wav_sub_1289_1537_0048.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	南泥湾	南泥湾	儿歌多多
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	南泥湾	南泥湾	上海杨浦少年艺校合唱团
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	南泥湾	南泥湾	儿歌多多
# [019:	20180725221100.wav_sub_514_750_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Satisfaction	Satisfaction	The Rolling Stones
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	(I Can't Get No) Satisfaction	(I Can't Get No) Satisfaction	The Rolling Stones
# [020:	20180725221101.wav_sub_1805_2119_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# [021:	20180725221101.wav_sub_2513_2827_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	我是你的女  L也是你的兵	我是你的女  L也是你的兵	李丹阳
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	我是你的女  L也是你的兵	我是你的女  L也是你的兵	李丹阳
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	我是你的女  L也是你的兵	我是你的女  L也是你的兵	李丹阳
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	我是你的女  L也是你的兵	我是你的女  L也是你的兵	李丹阳
# [022:	20180725221101.wav_sub_866_1108_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [023:	20180725231101.wav_sub_2054_2272_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	送亲歌	送亲歌	阿云嘎
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	送亲歌	送亲歌	阿云嘎
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	送亲歌	送亲歌	阿云嘎
# [024:	20180725231101.wav_sub_2288_2494_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	朋友们舞起来!	′ `′'朋友们舞_起来! ′′ ′	哈王林
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	朋友们舞起来!	′ `′'朋友们舞_起来! ′′ ′	哈王林
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	朋友们舞起来!	′ `′'朋友们舞_起来! ′′ ′	哈王林
# [025:	20180726001101.wav_sub_137_373_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	这_刻	这_刻	陈思思
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	这_刻	这_刻	陈思思
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	这_刻	这_刻	陈思思
# [026:	20180726001101.wav_sub_1577_1777_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	漂壳的蒙古马	漂壳的蒙古马	杭盖乐队
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Bounce	Bounce	Dj Drops
# [027:	20180726001101.wav_sub_2099_2305_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	敖包相会	敖包相会	黑骏马组合
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	敖包相会	敖包相会	黑骏马组合
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	敖包相会	敖包相会	黑骏马组合
# [028:	20180726001101.wav_sub_2555_2827_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的生活充满阳光	我们的生活充满阳光	至上励合
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的生活充满阳光	我们的生活充满阳光	至上励合
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的生活充满阳光	我们的生活充满阳光	至上励合
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	点赞中国	点赞中国	平安/云朵
# [029:	20180726031101.wav_sub_545_769_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	情人 (Live)	情人 (Live)	古巨墓
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	情人 (Live)	情人 (Live)	古巨墓
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	情人 (Live)	情人 (Live)	古巨墓
# [030:	20180726041101.wav_sub_1567_1785_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	安排好的人生	安排好的人生	白举纲
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	安排好的人生	安排好的人生	白举纲
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	安排好的人生	安排好的人生	白举纲
# [031:	20180726041101.wav_sub_811_1047_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	SaOChi Boy	SaOChi Boy	白举纲
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	SaOChi Boy	SaOChi Boy	白举纲
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	SaOChi Boy	SaOChi Boy	白举纲
# [032:	20180726051101.wav_sub_2315_2515_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# [033:	20180726051101.wav_sub_494_712_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [034:	20180726061101.wav_sub_739_1005_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Lost My Doll	Lost My Doll	Emme Packer
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Lost My Doll	Lost My Doll	Emme Packer
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Lost My Doll	Lost My Doll	Emme Packer
# [035:	20180726071101.wav_sub_460_732_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Edie (Ciao Baby) [acoustic]	Edie (Ciao Baby) [acoustic]	The Cult
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Edie (Ciao Baby) [acoustic]	Edie (Ciao Baby) [acoustic]	The Cult
# [036:	20180726081100.wav_sub_2383_2619_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL		梦中花
# 02m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL		梦中花
# 03m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL		梦中花
# [037:	20180726091101.wav_sub_2228_2650_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	II. Larhghetto - (Attacca)	II. Larhghetto - (Attacca)	Giuseppe Sinopoli
# 07m00s	SCREEN_NO_MATCH
# [038:	20180726141101.wav_sub_1274_1570_0036.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	瑶山夜歌	瑶山夜歌	北京金帆少年合唱团
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	瑶山夜歌	瑶山夜歌	北京金帆少年合唱团
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	瑶山夜歌	瑶山夜歌	北京金帆少年合唱团
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	瑶山夜歌	瑶山夜歌	北京金帆少年合唱团
# [039:	20180726151100.wav_sub_1193_1483_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	离开我你真的不难过	离开我你真的不难过	江凯文
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	离开我你真的不难过	离开我你真的不难过	江凯文
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	离开我你真的不难过	离开我你真的不难过	江凯文
# [040:	20180726151101.wav_sub_542_1270_0240.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为有你	_ ′` 因为′肴雳… __ '	王吉吉
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为有你	_ ′` 因为′肴雳… __ '	王吉吉
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为有你	_ ′` 因为′肴雳… __ '	王吉吉
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为有你	_ ′` 因为′肴雳… __ '	王吉吉
# [041:	20180726161101.wav_sub_1970_2278_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见， 我的爱人 (Live)	再见， 我的爱人 (Live)	王晰
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见， 我的爱人 (Live)	再见， 我的爱人 (Live)	王晰
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见， 我的爱人 (Live)	再见， 我的爱人 (Live)	王晰
# 05m00s	SCREEN_NO_MATCH
# [042:	20180726171100.wav_sub_2662_2928_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	带我飞吧	带我飞吧	顾峰
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	带我飞吧	带我飞吧	顾峰
# [043:	20180726171101.wav_sub_1505_1759_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Knocking on Heaven's Door (Live)	Knocking on Heaven's Door (Live)	罗琦
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Knocking on Heaven's Door (Live)	Knocking on Heaven's Door (Live)	罗琦
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Knocking on Heaven's Door (Live)	Knocking on Heaven's Door (Live)	罗琦
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Knocking on Heaven's Door (Live)	Knocking on Heaven's Door (Live)	罗琦
# [044:	20180726181101.wav_sub_1409_1645_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [045:	20180726181101.wav_sub_1805_2023_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Over The Mountains	Over The Mountains	Shanghai Philharmonic Orchestra/Peng Cao
# 02m00s	SCREEN_NO_MATCH
# [046:	20180726181101.wav_sub_581_859_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	太行春秋 - 看秧歌 (Watching Yanko)	太行春秋 - 看秧歌 (Watching Yanko)	俄罗斯佛罗内斯交响乐团
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	太行春秋 - 看秧歌 (Watching Yanko)	太行春秋 - 看秧歌 (Watching Yanko)	俄罗斯佛罗内斯交响乐团
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	太行春秋 - 看秧歌 (Watching Yanko)	太行春秋 - 看秧歌 (Watching Yanko)	俄罗斯佛罗内斯交响乐团
# [047:	20180726181101.wav_sub_893_1147_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	【京剧】 丑	【京剧】 丑	鲍元恺
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	【京剧】 丑	【京剧】 丑	鲍元恺
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	【京剧】 丑	【京剧】 丑	鲍元恺
# [048:	20180726191101.wav_sub_1484_1804_0060.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	友谊地久天长	友谊地久天长	上海小荧星合唱团
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	友谊地久天长	友谊地久天长	上海小荧星合唱团
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [049:	20180726191101.wav_sub_2060_2272_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	乘着歌声 的翅月旁	乘着歌声 的翅月旁	中国交响乐团附居少年及女子合唱团
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [050:	20180726191101.wav_sub_2087_2287_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	少年梦	少年梦	麦子杰
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	少年梦	少年梦	麦子杰
# [051:	20180726191101.wav_sub_2324_2704_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	小黄马	小黄马	奈热乐队
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	小黄马	小黄马	奈热乐队
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	小黄马	小黄马	奈热乐队
# [052:	20180726191101.wav_sub_635_931_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	仙踪	仙踪	赵净颐
# [053:	20180726201100.wav_sub_272_514_0018.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	快乐转载	快乐转载	胡彦斌
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	快乐转载	快乐转载	胡彦斌
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	快乐转载	快乐转载	胡彦斌
# [054:	20180726221101.wav_sub_2372_2626_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [055:	20180726221101.wav_sub_3080_3346_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [056:	20180726231100.wav_sub_3326_3538_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	太坦白	太坦白	李荣浩
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	太坦白	太坦白	李荣浩
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	太坦白	太坦白	李荣浩
# [057:	20180726231101.wav_sub_124_384_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	(Everything | Do) | Do It For You	(Everything | Do) | Do It For You	Bryan Adams
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	(Everything | Do) | Do It For You	(Everything | Do) | Do It For You	Bryan Adams
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	(Everything | Do) | Do It For You	(Everything | Do) | Do It For You	Bryan Adams
# [058:	20180727001105.wav_sub_1424_1684_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	好	最好	薛之谦
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	好	最好	薛之谦
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	好	最好	薛之谦
# [059:	20180727001105.wav_sub_2567_2797_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	笨蛋， 混蛋	笨蛋， 混蛋	陆虎/何洁
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	笨蛋， 混蛋	笨蛋， 混蛋	陆虎/何洁
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	笨蛋， 混蛋	笨蛋， 混蛋	陆虎/何洁
# [060:	20180727011103.wav_sub_653_901_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	女口果我没有爱过	女口果我没有爱过	谭维维
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	女口果我没有爱过	女口果我没有爱过	谭维维
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	女口果我没有爱过	女口果我没有爱过	谭维维
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	女口果我没有爱过	女口果我没有爱过	谭维维
# [061:	20180727021238.wav_sub_2503_2829_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	蝶 (蝴蝶)	蝶 (蝴蝶)	柴田淳(L碱尤 D榆允)
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL		冰
# 04m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL		冰
# 05m00s	SCREEN_NO_MATCH
# [062:	20180727031101.wav_sub_2645_2851_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	我可以抱你吗 (Live)	我可以抱你吗 (Live)	羽泉
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	我可以抱你吗 (Live)	我可以抱你吗 (Live)	羽泉
# [063:	20180727031102.wav_sub_2632_2844_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [064:	20180727031102.wav_sub_994_1296_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	学会相信	学会相信	黄雅莉
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	学会相信	学会相信	黄雅莉
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	学会相信	学会相信	黄雅莉
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	学会相信	学会相信	黄雅莉
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	学会相信	学会相信	黄雅莉
# [065:	20180727051102.wav_sub_719_949_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [066:	20180727071101.wav_sub_118_372_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	哪里哪里	哪里哪里	叶柔
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	哪里哪里	哪里哪里	叶柔
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	哪里哪里	哪里哪里	叶柔
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	哪里哪里	哪里哪里	叶柔
# [067:	20180727071101.wav_sub_97_357_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [068:	20180727091101.wav_sub_1118_1468_0024.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	Symphony No.9 in E minor, Op.95 "From the New World" - 2. Largo (第_乐章 有 活力的快板)	唰脚罐 隍n昱冀皇碧豪皇劳蜀′r莫最萝eW	Czech Philharmonic Orchestra/Jiri Belohlavek
# [069:	20180727091101.wav_sub_1547_1825_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Symphony No.9 in E minor, Op.95 "From the New World" - 2. Largo (第_乐章 有 活力的快板)	唰脚罐 隍n昱冀皇碧豪皇劳蜀′r莫最萝eW	Czech Philharmonic Orchestra/Jiri Belohlavek
# 02m00s	SCREEN_NO_MATCH
# [070:	20180727091101.wav_sub_1547_1825_0186.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# [071:	20180727091101.wav_sub_1832_2596_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# [072:	20180727091101.wav_sub_1832_2596_0066.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	月之故乡	月之故乡	群星
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	月之故乡	月之故乡	群星
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	月之故乡	月之故乡	群星
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Fanfares	Fanfares	Philip Jeck
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_NO_MATCH
# 07m00s	SCREEN_NO_MATCH
# 08m00s	SCREEN_NO_MATCH
# 09m00s	SCREEN_NO_MATCH
# 10m00s	SCREEN_NO_MATCH
# 11m00s	SCREEN_MATCHUP_EXTRACT_DONE	Oh Superman (Karaoke Version)	Oh Superman (Karaoke Version)	Vee Sing Zone
# [073:	20180727111101.wav_sub_185_415_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为爱你	因为爱你	邰正宵
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为爱你	因为爱你	邰正宵
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	因为爱你	因为爱你	邰正宵
# [074:	20180727111101.wav_sub_995_1261_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	源来罡爱	源来罡爱	邰正宵
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	源来罡爱 (2004年福音哥欠曲)	源来罡爱 (2004年福音哥欠曲)	邰正宵
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	源来罡爱 (2004年福音哥欠曲)	源来罡爱 (2004年福音哥欠曲)	邰正宵
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	源来罡爱	源来罡爱	邰正宵
# [075:	20180727131101.wav_sub_1793_2011_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	等爱走了 以后	等爱走了 以后	杨莫
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	等爱走了 以后	等爱走了 以后	杨莫
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	等爱走了 以后	等爱走了 以后	杨莫
# [076:	20180727141101.wav_sub_1340_1702_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_NO_MATCH
# [077:	20180727141101.wav_sub_3260_3586_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	嘎达梅林	嘎达梅林	胡松华
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	嘎达梅林	嘎达梅林	胡松华
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	嘎达梅林	嘎达梅林	胡松华
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	嘎达梅林	嘎达梅林	胡松华
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	小河淌水 (Live)	小河淌水 (Live)	昊碧霞
# [078:	20180727151100.wav_sub_2686_2910_0174.wav]
# 00m00s	SCREEN_MATCHING
# [079:	20180727151101.wav_sub_2408_2920_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		清晨	沈小岑
# 05m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		清晨	沈小岑
# 06m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		清晨	沈小岑
# 07m00s	SCREEN_MATCHUP_EXTRACT_DONE	多彩的季节	多彩的季节	杨培国
# 08m00s	SCREEN_NO_MATCH
# [080:	20180727151101.wav_sub_530_1000_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	山歌牵出月壳来	山歌牵出月壳来	严当当
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	山歌牵出月壳来	山歌牵出月壳来	严当当
# 07m00s	SCREEN_MATCHUP_EXTRACT_DONE	山歌牵出月壳来	山歌牵出月壳来	严当当
# [081:	20180727161100.wav_sub_3326_3562_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	听 说	听 说	魏女口昀
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	听 说	听 说	魏女口昀
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	听 说	听 说	魏女口昀
# [082:	20180727181101.wav_sub_2104_2310_0018.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	起跑	起跑	连诗雅
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	起跑	起跑	连诗雅
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	起跑	起跑	连诗雅
# [083:	20180727191101.wav_sub_2585_2905_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	What's Up (Live)	What's Up (Live)	李玟
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	What's Up (Live)	What's Up (Live)	李玟
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	What's Up (Live)	What's Up (Live)	李玟
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	What's Up (Live)	What's Up (Live)	李玟
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	What's Up (Live)	What's Up (Live)	李玟
# [084:	20180727191101.wav_sub_760_996_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的光辉岁月	我们的光辉岁月	周游格
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的光辉岁月	我们的光辉岁月	周游格
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	我们的光辉岁月	我们的光辉岁月	周游格
# [085:	20180727211101.wav_sub_2267_2527_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	布 酒歌	贡布酒歌	德乾旺姆
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	布 酒歌	贡布酒歌	德乾旺姆
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	布 酒歌	贡布酒歌	德乾旺姆
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	布 酒歌	贡布酒歌	德乾旺姆
# [086:	20180727211101.wav_sub_842_1132_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [087:	20180727231100.wav_sub_2395_2601_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [088:	20180728001101.wav_sub_1532_1774_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	壮志在我胸 (Live)	壮志在我胸 (Live)	李宗盛
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	壮志在我胸 (Live)	壮志在我胸 (Live)	李宗盛
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	壮志在我胸 (Live)	壮志在我胸 (Live)	李宗盛
# [089:	20180728011101.wav_sub_1043_1309_0006.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	走在春天的路上 (Live)	走在春天的路上 (Live)	吕薇
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	走在春天的路上 (Live)	走在春天的路上 (Live)	吕薇
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	走在春天的路上 (Live)	走在春天的路上 (Live)	吕薇
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	走在春天的路上 (Live)	走在春天的路上 (Live)	吕薇
# [090:	20180728031101.wav_sub_1450_1686_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	星光	星光	郑俊弘
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	星光	星光	郑俊弘
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	星光	星光	郑俊弘
# [091:	20180728031101.wav_sub_1954_2154_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	我木目信 (Live)	我木目信 (Live)	张靓颖
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	我木目信 (Live)	我木目信 (Live)	张靓颖
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	我木目信 (Live)	我木目信 (Live)	张靓颖
# [092:	20180728031101.wav_sub_2065_2301_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	错的情错的人	错的情错的人	Showoff
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	错的情错的人	错的情错的人	Showoff
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	错的情错的人	错的情错的人	Showoff
# [093:	20180728031101.wav_sub_3205_3435_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summertime	Summertime	Scarlett Johansson
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summertime	Summertime	Scarlett Johansson
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summertime	Summertime	Scarlett Johansson
# [094:	20180728031101.wav_sub_475_819_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	XII. The Catacombs (Sepulchrum Romanum)	XII. The Catacombs (Sepulchrum Romanum)	Va|ery Abisalovich Gergiev/Vienna Philharmonic Orchestra
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# [095:	20180728041100.wav_sub_484_696_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summer Bossa	Summer Bossa	谢春花
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summer Bossa	Summer Bossa	谢春花
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Summer Bossa	Summer Bossa	谢春花
# [096:	20180728041100.wav_sub_587_883_0216.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	配角	配角	顾海滨
# [097:	20180728041101.wav_sub_1787_2095_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [098:	20180728061101.wav_sub_1201_1563_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Kapola(0riginal Mix) (Remix)	Kapola(0riginal Mix) (Remix)	Afro Carrib
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Nemesis	Nemesis	LP Project
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Slut Machine (Original Mix)	Slut Machine (Original Mix)	Skail Master M
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Find My World (Radio Edit)	Find My World (Radio Edit)	Dandeej/Simona Mase
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	Freak Show(0riginal Mix) (Remix)	Freak Show(0riginal Mix) (Remix)	未知歌手
# [099:	20180728061101.wav_sub_2467_2739_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	虚度时光	虚度时光	高凯元
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	虚度时光	虚度时光	高凯元
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	虚度时光	虚度时光	高凯元
# [100:	20180728061101.wav_sub_2500_2724_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Reach Out_Giorgio Moroder Featuring Paul Engemann	Reach Out_GiO「g昌言g暨篱亘写宣「 Featuring Paul	Giorgio Moroder
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Reach Out_Giorgio Moroder Featuring Paul Engemann	Reach Out_GiO「g昌言g暨篱亘写宣「 Featuring Paul	Giorgio Moroder
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Reach Out_Giorgio Moroder Featuring Paul Engemann	Reach Out_GiO「g昌言g暨篱亘写宣「 Featuring Paul	Giorgio Moroder
# [101:	20180728071101.wav_sub_1390_1830_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [102:	20180728071101.wav_sub_1390_1830_0192.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	X-F|LES' 丁HEME (Remix)	X-F|LES' 丁HEME (Remix)	Triple x
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Zombie (Mix Cut)	Zombie (Mix Cut)	RAND
# 03m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	上头就高碱崖姬万岁 (Remix)	上头就高碱崖姬万岁 (Remix)
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Flashback (Remix)	Flashback (Remix)	Armin Van Buuren
# [103:	20180728081101.wav_sub_2686_2892_0006.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		感动	汤非
# 03m00s	SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL		感动	汤非
# [104:	20180728081101.wav_sub_982_1236_0000.wav]
# 00m00s	SCREEN_MATCHING
# [105:	20180728131101.wav_sub_1007_1255_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	无处不乐	无处不乐	吉克隽逸
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	无处不乐 (合唱)	无处不乐 (合唱)	华语群星
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	无处不乐 (合唱)	无处不乐 (合唱)	华语群星
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	无处不乐 (合唱)	无处不乐 (合唱)	华语群星
# [106:	20180728151101.wav_sub_1133_1405_0222.wav]
# 00m00s	SCREEN_MATCHING
# [107:	20180728151101.wav_sub_1397_1639_0054.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	古乐年华	苦乐年华	范琳琳
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	古乐年华	苦乐年华	范琳琳
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	古乐年华	苦乐年华	范琳琳
# [108:	20180728151101.wav_sub_2162_2386_0006.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [109:	20180728151101.wav_sub_2398_2628_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	永远有个你	永远有个你	詹小栎
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	永远有个你	永远有个你	詹小栎
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	永远有个你	永远有个你	詹小栎
# [110:	20180728151101.wav_sub_599_1141_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	‘g 的中国心 _^董具藜”.灞	_曹馨暮的帼心 黜 气腻	杨钰莹/陆俊昊
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	‘g 的中国心 _^董具藜”.灞	_曹馨暮的帼心 黜 气腻	杨钰莹/陆俊昊
# [111:	20180728171101.wav_sub_1363_1563_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	当我成了你	当我成了你	呆宝静
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	当我成了你	当我成了你	呆宝静
# [112:	20180728181101.wav_sub_271_531_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	黄土高坡	黄土高坡	田震
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	黄土高坡	黄土高坡	田震
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	黄土高坡	黄土高坡	杭天琪
# [113:	20180728181101.wav_sub_428_670_0006.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	相约	相约	潘劲东
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	相约	相约	潘劲东
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	相约	相约	潘劲东
# [114:	20180728181101.wav_sub_698_952_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	拉着你的手	拉着你的手
# 02m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	拉着你的手	拉着你的手
# 03m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	拉着你的手	拉着你的手
# 04m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	拉着你的手	拉着你的手
# [115:	20180728181101.wav_sub_958_1242_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	弹着吉他的少年	弹着吉他的少年	新裤子
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	弹着吉他的少年	弹着吉他的少年	新裤子
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	弹着吉他的少年	弹着吉他的少年	新裤子
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	弹着吉他的少年	弹着吉他的少年	新裤子
# [116:	20180728191101.wav_sub_2233_2451_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	盛夏 (小镇吉他版)	盛夏 (小镇吉他版)	黄姗姗
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	盛夏 (小镇吉他版)	盛夏 (小镇吉他版)	黄姗姗
# [117:	20180728191101.wav_sub_979_1215_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	左手指月 (电视剧 《香蜜沉沉烬如霜》 片 尾曲)	左手指月 (电视剧 《香蜜沉沉烬如霜》 片 尾曲)	萨顶顶
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	左手指月 (电视剧 《香蜜沉沉烬如霜》 片 尾曲)	左手指月 (电视剧 《香蜜沉沉烬如霜》 片 尾曲)	萨顶顶
# [118:	20180728221100.wav_sub_3169_3453_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	模样	模样	老狠
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	模样	模样	老狠
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	模样	模样	老狠
# [119:	20180728221101.wav_sub_128_898_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_NO_MATCH
# 07m00s	SCREEN_NO_MATCH
# 08m00s	SCREEN_NO_MATCH
# 09m00s	SCREEN_NO_MATCH
# 10m00s	SCREEN_NO_MATCH
# 11m00s	SCREEN_NO_MATCH
# 12m00s	SCREEN_NO_MATCH
# [120:	20180728221101.wav_sub_1565_1783_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Toccata For All Soul's Day (1992) Tempestoso E Lacerente	Toccata For All SOu亡亘c巳孛菖醛喜e992) Tempestoso E	Dimiter Christoff
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [121:	20180728221101.wav_sub_1811_2065_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [122:	20180728221101.wav_sub_2204_2434_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [123:	20180728221101.wav_sub_2438_2656_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [124:	20180728221101.wav_sub_944_1348_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	Tabuh Kreasi Baru Eka Cita	Tabuh Kreasi Baru Eka Cita	Semara Sandhi
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	带派开场 (Remix)	带派开场 (Remix)	小阿诺
# [125:	20180728231101.wav_sub_1760_2224_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_NO_MATCH
# 07m00s	SCREEN_NO_MATCH
# [126:	20180728231101.wav_sub_2318_2668_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# [127:	20180728231101.wav_sub_2690_2890_0000.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# [128:	20180728231101.wav_sub_3256_3480_0120.wav]
# 00m00s	SCREEN_MATCHING
# [129:	20180729001101.wav_sub_3125_3331_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	凤凰与蝴蝶	凤凰与蝴蝶
# 02m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	凤凰与蝴蝶	凤凰与蝴蝶
# 03m00s	SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL	凤凰与蝴蝶	凤凰与蝴蝶
# [130:	20180729001101.wav_sub_847_1095_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [131:	20180729021101.wav_sub_622_840_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	(They Long To Be) Close To You	(They Long To Be) Close To You	Carpenters
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	(They Long to Be) Close to You	(They Long to Be) Close to You	Carpenters
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	(They Long to Be) Close to You	(They Long to Be) Close to You	Carpenters
# [132:	20180729031101.wav_sub_1738_1944_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见吧 喵小姐 (Live)	再见吧 喵小姐 (Live)	王晓天
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见吧 喵小姐 (Live)	再见吧 喵小姐 (Live)	王晓天
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	再见吧 喵小姐 (Live)	再见吧 喵小姐 (Live)	王晓天
# [133:	20180729031101.wav_sub_1951_2193_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	只怪 自 己活该 (Live)	只怪 自 己活该 (Live)	羽田
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	只怪 自 己活该 (Live)	只怪 自 己活该 (Live)	羽田
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	只怪 自 己活该 (Live)	只怪 自 己活该 (Live)	羽田
# [134:	20180729041101.wav_sub_1360_1572_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	有本事	有本事	动力火车/丁ank
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	有本事	有本事	动力火车/丁ank
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	有本事	有本事	动力火车/丁ank
# [135:	20180729041101.wav_sub_2254_2496_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# [136:	20180729051101.wav_sub_1816_2310_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_NO_MATCH
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# 06m00s	SCREEN_NO_MATCH
# 07m00s	SCREEN_NO_MATCH
# 08m00s	SCREEN_MATCHUP_EXTRACT_DONE	Bajo-Concert	Bajo-Concert	Danie| Kientzy
# [137:	20180729051101.wav_sub_2785_3093_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	酒哥欠	酒哥欠	杭盖乐队
# 03m00s	SCREEN_NO_MATCH
# 04m00s	SCREEN_NO_MATCH
# 05m00s	SCREEN_NO_MATCH
# [138:	20180729071101.wav_sub_367_753_0012.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	Cry On Your Smile	Cry On Your Smile	Various Artists
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	Cry On Your Smile	Cry On Your Smile	Various Artists
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	Cry On Your Smile	Cry On Your Smile	Various Artists
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	Cry On Your Smile	Cry On Your Smile	Various Artists
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	Cry On Your Smile	Cry On Your Smile	Various Artists
# [139:	20180729081100.wav_sub_1702_2172_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	新甜言  田野 瞄	新甜言蜜语	楚小波
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	新甜言  田野 瞄	新甜言蜜语	楚小波
# [140:	20180729081100.wav_sub_1702_2172_0426.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# [141:	20180729081101.wav_sub_2549_2923_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_NO_MATCH
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	情对祖国讲 爱对祖国说	情对祖国讲 爱对祖国说	阿鲁阿卓
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	情对祖国讲 爱对祖国说	情对祖国讲 爱对祖国说	阿鲁阿卓
# 04m00s	SCREEN_MATCHUP_EXTRACT_DONE	情对祖国讲 爱对祖国说	情对祖国讲 爱对祖国说	阿鲁阿卓
# 05m00s	SCREEN_MATCHUP_EXTRACT_DONE	扬鞭策马追梦忙	扬鞭策马追梦忙	泽旺多吉
# 06m00s	SCREEN_MATCHUP_EXTRACT_DONE	扬鞭策马追梦忙	扬鞭策马追梦忙	泽旺多吉
# [142:	20180729081101.wav_sub_2600_2902_0000.wav]
# 00m00s	SCREEN_MATCHING
# 01m00s	SCREEN_NO_MATCH
# [143:	20180729081101.wav_sub_2600_2902_0126.wav]
# 00m00s	SCREEN_NO_MATCH
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	俺们的贴心人	俺们的贴心人	石占明
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	俺们的贴心人	俺们的贴心人	石占明
# [144:	20180729091101.wav_sub_487_717_0000.wav]
# 00m00s	SCREEN_SKIP_FIRST_MATCHUP
# 01m00s	SCREEN_MATCHUP_EXTRACT_DONE	THE DROP (Stonebank Remix)	THE DROP (Stonebank Remix)	Gammer
# 02m00s	SCREEN_MATCHUP_EXTRACT_DONE	THE DROP (Stonebank Remix)	THE DROP (Stonebank Remix)	Gammer
# 03m00s	SCREEN_MATCHUP_EXTRACT_DONE	THE DROP (Stonebank Remix)	THE DROP (Stonebank Remix)	Gammer
