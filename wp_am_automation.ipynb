# %% [markdown]
# # SW Preparation
# ### ADB tool
# * [Download the ADB zip file for Windows](https://dl.google.com/android/repository/platform-tools-latest-windows.zip)
# * Extract the contents of this ZIP file into an easily accessible folder (such as C:\android\platform-tools)
# * Connect your android phone / tablet and open command prompt to test if adb is working, detail commands can refer this [article](https://www.howtogeek.com/125769/how-to-install-and-use-abd-the-android-debug-bridge-utility/)
# ```
# C:\Users\rowe8002\AppData\Local\Android\Sdk\platform-tools>adb devices
# List of devices attached
# QMKNW17321007584        device
# ```
# * Add adb executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### OCR tool
# * [Download tesseract Windows binary](https://github.com/tesseract-ocr/tesseract/wiki/Downloads)
# * Install it as its installer instructed
# * Open command prompt to verify the install
# ```
# C:\Users\rowe8002>tesseract --version
# tesseract 3.05.02
#  leptonica-1.75.3
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.3) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.2.0
# ```
# * Add tessract executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### Python package
# * We recommand anacond3 for python package
#     * run **conda search \[packagename\]** to find the package and **conda install \[packagename\]** to install it.
#     * In case the package doesn't in anaconda repository, run **pip search \[packagename\]** to find the package and **pip install \[packagename\]** to install it
# * **PIL / threading / keyboard / os / pyaudio / subprocess / time / wave** are the packages required for this program
#
# ### Third party music recognition APP
# * QQ music (this program was initally written for QQ music)
#
# # HW Preparation
# * android phone (or tablet)
# * usb cable for PC and andriod device connection
#
# # Notes
# * below code is adjust to adapt 1200x1920 screen size tablet, if you use a different screen size android device, you need to update image crop postion & adb input tap postion accordingly.
# * I would recommand to use big screen device like tablet to run the test, as the track title maybe displayed to 3+ lines if using small screen device, which increase the inaccuracy of ocr.
#
# *Any question please contact wei.rong@nielsen.com*

# %%
#!usr/bin/env python  
#coding=utf-8  

from PIL import Image
from threading import Thread
import keyboard
import os
import pyaudio
import subprocess
import time
import wave

# %%
########functions for wav playing########
def _wp_init(f):
#    print("_wp_init()...")
    p = pyaudio.PyAudio()  
    #open stream  
    stream = p.open(format = p.get_format_from_width(f.getsampwidth()),  
                channels = f.getnchannels(),  
                rate = f.getframerate(),  
                output = True)
    return p, stream

def _wp_run(f,c,s):
#    print("_wp_run()...")
    data = f.readframes(c)
    while data:
        if keyboard.is_pressed('q'): break
        s.write(data)
        data = f.readframes(c)

def _wp_deInit(s,p,f):
#    print("_wp_deInit()...")
    s.stop_stream()  
    s.close()
    f.close()
    p.terminate()

def wavPlaying(file):
    chunk = 1024
    wavfile = wave.open(file,"rb")  
    p, stream = _wp_init(wavfile)
    _wp_run(wavfile,chunk,stream)
    _wp_deInit(stream,p,wavfile)    

########functions for image crop########
def _im_crop_save(src,des,box):
    img = Image.open(src+".png")
    img2 = img.crop(box)
    img2.save(des+".png")

def _im_add_suffix(src,suffix):
    if os.path.isfile(src+'.png'):
        os.rename(src+'.png',src+'_'+suffix+'.png')
    
def _im_cleanup(name):
    for i in range(3):
        for j in ['png','txt']:
            f = name+'_check0'+str(i+1)+'.'+j
            try:
                os.remove(f)
            except OSError as e:
                #print(e)
                pass

def _im_cleanup_extracted_string(s):
    if s[:4] == '_ 一 ' and s[-4:] == ' 一 _': s = s[4:-4]
    if s[:2] == '一 ' and s[-2:] == ' 一': s = s[2:-2]
    if s[:2] == '— ' and s[-2:] == ' —': s = s[2:-2]
    if s[:1] == '_' and s[-1:] == '_': s = s[1:-1]
    return s.strip()
    
def _im_extract_track_artist(src):
    ret, error, track1, track2, artist = True, [], '', '', ''

    _im_crop_save(src, src+"_matchup_track", (120, 1255, 1080, 1365))
    
    track1 = _ocr_to_string(src+"_matchup_track")
    track1 = _im_cleanup_extracted_string(track1)
    if not len(track1): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL')

    #try with psm7 as single line 
    track2 = _ocr_to_string(src+"_matchup_track",False,'-l chi_sim+eng -psm 7')
    track2 = _im_cleanup_extracted_string(track2)
    if not len(track2): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_PSM7_FAIL')

    _im_crop_save(src, src+"_matchup_artist", (120, 1365, 1080, 1405))
    artist = _ocr_to_string(src+"_matchup_artist",False,'-l chi_sim+eng -psm 7')
    artist = _im_cleanup_extracted_string(artist)
    if not len(artist): error.append('SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL')

    if error == []: error.append('SCREEN_MATCHUP_EXTRACT_DONE')
    return ret, error, track1, track2, artist

########functions for image ocr########
def _ocr_to_string(img, cleanup=False, plus='-l chi_sim+eng'):
    subprocess.check_output('tesseract '+img+'.png'+' '+img+' '+plus, shell=True)
    text = ''
    with open(img + '.txt', 'r', encoding='UTF-8') as f:
        text = f.read().strip().replace('\n',' ')
    if cleanup:
        os.remove(img + '.txt')
    return text

########functions for android manipulation########
def _am_formatDuration(d):
    mins = d//60;
    secs = d - mins*60
    return "%02dm%02ds"%(mins,secs)

def _am_check_string(s):
    if '\"' in s: s=s.replace('\"','')
    if ',' in s: s="\"%s\""%s
    return s

def _am_getDevices():
    cmd = "adb devices"
    out = subprocess.check_output(cmd.split())
    list = out.decode('utf-8').strip().split('\r\n')
    #print(list)
    return list

def _am_init():
    devices = _am_getDevices()
    if len(devices) <= 1 or '\tdevice' not in devices[-1]:
        cmd = "adb kill-server"
        out = subprocess.check_output(cmd.split())
        time.sleep(5)
        cmd = "adb start-server"
        out = subprocess.check_output(cmd.split())
        list = out.decode('utf-8').strip().split('\r\n')
        print(list)
        if 'successfully' not in list[-1]: return False
    return True

def _am_getScreenSize(st):
    print("%s:_am_getScreenSize " % _am_formatDuration(int(time.time()-st)),end='')
    cmd = "adb shell wm size"
    out = subprocess.check_output(cmd.split())
    size = tuple((out.decode('utf-8').strip().split('\r\n')[0].split(' ')[2].split('x')))
    print(size)
    return size

def _am_launchApp(st):
    time.sleep(2)
    print("%s:_am_launchApp" % _am_formatDuration(int(time.time()-st)))

def _am_CaptureFullScreen(des):
    cmd = "adb shell screencap -p /sdcard/screencap.png"
    out = subprocess.check_output(cmd.split())
    cmd = "adb pull /sdcard/screencap.png %s%s" % (des,".png")
    out = subprocess.check_output(cmd.split())
    if 'pulled' not in out.decode('utf-8').strip():
        print("%s:screencap or pull failed, exit..." % _am_formatDuration(int(time.time()-st)))
        return False, "SCREENCAP_OR_PULL_FAILED"
    return True, "SCREENCAP_AND_PULL_DONE"

def _am_pressBackThenRec():
    cmd = "adb shell input tap 40 90"           #this is back arrow position
    out = subprocess.check_output(cmd.split())
    cmd = "adb shell input tap 300 1715"        #this is recognition icon position
    out = subprocess.check_output(cmd.split())

def _am_pressRetry():
    cmd = "adb shell input tap 600 1530"        #this is re-try buttom
    out = subprocess.check_output(cmd.split())
    cmd = "adb shell input tap 300 1715"        #this is recognition icon position
    out = subprocess.check_output(cmd.split())
    
def _am_onScreenAction(fn,ss,st,rc):
#    print("%s:_am_onScreenAction " % _am_formatDuration(int(time.time()-st)), end='')
    print("%s,%s," % (fn,_am_formatDuration(int(time.time()-st))), end='')
    
    ret, err = True, 'SCREEN_UNKNOWN'

    #outdir = "_out"
    #if os.path.isdir(outdir): os.rename(outdir,outdir+'_'+time.strftime('%Y%m%d_%H%M%S',time.localtime()))
    #os.makedirs(outdir, exist_ok=True)

    #caputre the full sceen
    t = _am_formatDuration(int(time.time()-st))
    name = os.path.join(outdir,"%s_%s" % (fn,t))
    ret, err = _am_CaptureFullScreen(name)
    if not ret: return ret,err

    #crop to have multiple check-point sub-images to identify screen
    _im_crop_save(name, name+"_check01", (0, 180, 1200, 240))   #匹配到以下结果
    _im_crop_save(name, name+"_check02", (0, 610, 1200, 675))   #请求超时/未匹配到结果/无网络连接
    _im_crop_save(name, name+"_check03", (0, 1505, 1200, 1555)) #重试/停止识别/开始识别/重新识别/查看识别历史
    #_im_crop_save(name, name+"_check04", (0, 1750, 1200, 1795)) #听歌识曲 哼唱识别

    if '匹配到以下结果' in _ocr_to_string(name+"_check01"):
        #print(" SCREEN_MATCH_UP")
        ret, err, track1, track2, artist = _im_extract_track_artist(name)
        errStr = '|'.join(err)
        errStr = _am_check_string(errStr)
        track1 = _am_check_string(track1)
        track2 = _am_check_string(track2)
        artist = _am_check_string(artist)
        if rc != 0: #if first round screen is match_up, skip it as it may be presenting the previous track meta
            print("%s,"%errStr,end='')
            print("%s,"%track1,end='')
            print("%s,"%track2,end='')
            print("%s"%artist,end='')
            skipFirstMatchUpScreen = True
        else: print('SCREEN_SKIP_FIRST_MATCHUP',end='')
        _im_add_suffix(name,'matchup')
        _am_pressBackThenRec()
        time.sleep(5)
    elif '未匹配到结果' in _ocr_to_string(name+"_check02"):
        print("SCREEN_NO_MATCH",end='')
        ret, err =  True, 'SCREEN_NO_MATCH'
        _im_add_suffix(name,'nomatch')
        _am_pressBackThenRec()
    elif '请求超时' in _ocr_to_string(name+"_check02"):
        print("SCREEN_REQ_TIMEOUT",end='')
        ret, err =  True, 'SCREEN_REQ_TIMEOUT'
        _im_add_suffix(name,'timeout')
        _am_pressRetry()
    elif '发生错误了' in _ocr_to_string(name+"_check02"):
        print("SCREEN_ERROR_OCCUR",end='')
        ret, err =  True, 'SCREEN_ERROR_OCCUR'
        _im_add_suffix(name,'errOccur')
        _am_pressRetry()
    elif '停止识别' in _ocr_to_string(name+"_check03"):
        print("SCREEN_MATCHING",end='')
        ret, err =  True, 'SCREEN_MATCHING'
        _im_add_suffix(name,'matching')
    else:
        print("SCREEN_UNKNOWN",end='')
        ret, err = True, 'SCREEN_UNKNOWN'
        _im_add_suffix(name,'unkown')
    
    _im_cleanup(name)
    print('\n',end='')
    return ret, err

def androidManipulation(t,fn):
    startTime = time.time()
    if not _am_init():
        print("android manipulation exit due to adb init failure...")
        return

#    screenSize = _am_getScreenSize(startTime)
#    _am_launchApp(startTime)
#    print(t.ident)
    screenSize = ('1200', '1920')
    roundCount = 0 #in case the match up screen is presenting previous recognized track
    while t.isAlive():
        time.sleep(5)
        ret,errorInfo = _am_onScreenAction(fn,screenSize,startTime,roundCount)
        roundCount = roundCount + 1
        if not ret:
            print(errorInfo)
            break

########wav play & android manipulation threads########
def main(f):
    threadWp = Thread(target=wavPlaying, args=(f,))
    threadWp.start()

    threadAm = Thread(target=androidManipulation, args=(threadWp,os.path.splitext(os.path.basename(f))[0],))
    threadAm.start()

    threadWp.join()
    threadAm.join()

# %%
wavFolder = 'wav_folder'
#wavFolder = 'wav_folder_test'

fileList = os.listdir(wavFolder)
wavList = []
for i in fileList:
    ext = os.path.splitext(os.path.basename(i))[1]
    if '.wav' == ext:
        wavList.append(i)

outdir = "_out"
if os.path.isdir(outdir): os.rename(outdir,outdir+'_'+time.strftime('%Y%m%d_%H%M%S',time.localtime()))
os.makedirs(outdir, exist_ok=True)

c = 0
for i in sorted(wavList):
    c = c + 1
    print("==%03d=="%c)
#    print("\n====================")
#    print("[%03d: %s]"%(c,i))
    main(os.path.join(wavFolder,i))
# Out:
# ==001==
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,00m05s,SCREEN_MATCHING
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,00m25s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,00m51s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,01m19s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,01m44s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,02m09s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,02m35s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647,03m02s,SCREEN_MATCHUP_EXTRACT_DONE,阳 光下,阳 光下,满江
# ==002==
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,00m05s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,00m23s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,00m38s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,00m56s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,01m10s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,01m29s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,01m44s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,02m02s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,02m16s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,02m34s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997,02m49s,SCREEN_UNKNOWN
# ==003==
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,00m06s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,00m31s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,00m49s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,01m03s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,01m21s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,01m36s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,01m54s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,02m08s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,02m26s,SCREEN_NO_MATCH
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,02m40s,SCREEN_MATCHING
# cn-t1-03-01_3097_20180717071101.wav_sub_738_917,02m59s,SCREEN_NO_MATCH
# ==004==
# cn-t1-03-01_3124_20180718071101.wav_sub_1967_2027,00m05s,SCREEN_MATCHING
# cn-t1-03-01_3124_20180718071101.wav_sub_1967_2027,00m23s,SCREEN_NO_MATCH
# cn-t1-03-01_3124_20180718071101.wav_sub_1967_2027,00m38s,SCREEN_MATCHING
# cn-t1-03-01_3124_20180718071101.wav_sub_1967_2027,00m55s,SCREEN_NO_MATCH
# ==005==
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,00m05s,SCREEN_MATCHING
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,00m23s,SCREEN_NO_MATCH
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,00m38s,SCREEN_MATCHING
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,00m57s,SCREEN_NO_MATCH
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,01m12s,SCREEN_MATCHING
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,01m29s,SCREEN_NO_MATCH
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,01m44s,SCREEN_MATCHING
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,02m01s,SCREEN_NO_MATCH
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,02m16s,SCREEN_MATCHING
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,02m35s,SCREEN_NO_MATCH
# cn-t1-03-01_3125_20180718081101.wav_sub_476_656,02m49s,SCREEN_MATCHING
# ==006==
# cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558,00m05s,SCREEN_NO_MATCH
# cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558,00m20s,SCREEN_MATCHUP_EXTRACT_DONE,视讯 电话,视讯 电话,程恢弘
# cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558,00m45s,SCREEN_MATCHUP_EXTRACT_DONE,视讯 电话,视讯 电话,程恢弘
# cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558,01m09s,SCREEN_MATCHUP_EXTRACT_DONE,视讯 电话,视讯 电话,程恢弘
# cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558,01m34s,SCREEN_MATCHUP_EXTRACT_DONE,视讯 电话,视讯 电话,程恢弘
# ==007==
# cn-t1-04-01_3123_20180718061101.wav_sub_2093_2117,00m05s,SCREEN_MATCHING
# cn-t1-04-01_3123_20180718061101.wav_sub_2093_2117,00m23s,SCREEN_NO_MATCH
# ==008==
# cn-t1-05-01_3080_20180716141101.wav_sub_3356_3362,00m05s,SCREEN_MATCHING
# ==009==
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,00m05s,SCREEN_NO_MATCH
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,00m21s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,00m45s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,01m10s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,01m34s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,01m59s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,02m24s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663,02m50s,SCREEN_MATCHUP_EXTRACT_DONE,胃春终老,胃春终老,一 Robynn & Kendy —
# ==010==
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,00m30s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,00m54s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,01m18s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,01m42s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,02m06s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,02m30s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# cn-t1-05-01_3088_20180716221101.wav_sub_515_689,02m54s,SCREEN_MATCHUP_EXTRACT_DONE,口乎 _]及,口乎 _]及,丢火车乐队
# ==011==
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,00m31s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,00m55s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,01m20s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,01m45s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,02m09s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,02m34s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# cn-t1-05-01_3089_20180716231101.wav_sub_866_1040,02m59s,SCREEN_MATCHUP_EXTRACT_DONE,不思议少年,不思议少年,易安音乐社
# ==012==
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,00m05s,SCREEN_MATCHING
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,00m23s,SCREEN_MATCHUP_EXTRACT_DONE,Sunshine and Moonlight,Sunshine and Moonlight,一 安田寿之(睾矿尤 匕 L693) —
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,00m50s,SCREEN_MATCHUP_EXTRACT_DONE,想用你名 字命名 的歌,想用你名 字命名 的歌,木丽妍
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,01m15s,SCREEN_MATCHUP_EXTRACT_DONE,想用你名 字命名 的歌,想用你名 字命名 的歌,木丽妍
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,01m40s,SCREEN_MATCHUP_EXTRACT_DONE,想用你名 字命名 的歌,想用你名 字命名 的歌,木丽妍
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,02m05s,SCREEN_MATCHUP_EXTRACT_DONE,想用你名 字命名 的歌,想用你名 字命名 的歌,木丽妍
# cn-t1-05-01_3091_20180717011103.wav_sub_344_512,02m30s,SCREEN_MATCHUP_EXTRACT_DONE,想用你名 字命名 的歌,想用你名 字命名 的歌,木丽妍
# ==013==
# cn-t1-05-01_3091_20180717011103.wav_sub_827_953,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3091_20180717011103.wav_sub_827_953,00m33s,SCREEN_MATCHUP_EXTRACT_DONE,从此跟着你流浪去很远的地方,从此跟着你流浪去很远的地方,— ReDor锐豆乐队 一
# cn-t1-05-01_3091_20180717011103.wav_sub_827_953,00m59s,SCREEN_MATCHUP_EXTRACT_DONE,从此跟着你流浪去很远的地方,从此跟着你流浪去很远的地方,— ReDor锐豆乐队 一
# cn-t1-05-01_3091_20180717011103.wav_sub_827_953,01m27s,SCREEN_MATCHUP_EXTRACT_DONE,从此跟着你流浪去很远的地方,从此跟着你流浪去很远的地方,— ReDor锐豆乐队 一
# cn-t1-05-01_3091_20180717011103.wav_sub_827_953,01m54s,SCREEN_MATCHUP_EXTRACT_DONE,从此跟着你流浪去很远的地方,从此跟着你流浪去很远的地方,— ReDor锐豆乐队 一
# ==014==
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,00m05s,SCREEN_MATCHING
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,00m28s,SCREEN_NO_MATCH
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,00m46s,SCREEN_MATCHUP_EXTRACT_DONE,有心,有心,张玉珊
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,01m13s,SCREEN_MATCHUP_EXTRACT_DONE,有心,有心,张玉珊
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,01m39s,SCREEN_MATCHUP_EXTRACT_DONE,有心,有心,张玉珊
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,02m07s,SCREEN_MATCHING
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,02m29s,SCREEN_MATCHUP_EXTRACT_DONE,有心,有心,范振锋/张玉珊
# cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543,02m57s,SCREEN_MATCHUP_EXTRACT_DONE,有心,有心,范振锋/张玉珊
# ==015==
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,00m59s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,01m25s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,01m52s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,02m20s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669,02m48s,SCREEN_MATCHUP_EXTRACT_DONE,沉默的士高,沉默的士高,王菀之
# ==016==
# cn-t1-05-01_3118_20180718011101.wav_sub_1607_1655,00m06s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3118_20180718011101.wav_sub_1607_1655,00m33s,SCREEN_MATCHUP_EXTRACT_DONE,We Just Call It Love,We Just Call It Love,肆嚣乐队
# ==017==
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,00m05s,SCREEN_MATCHING
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,00m24s,SCREEN_NO_MATCH
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,00m39s,SCREEN_MATCHING
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,01m00s,SCREEN_NO_MATCH
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,01m15s,SCREEN_MATCHING
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,01m34s,SCREEN_NO_MATCH
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,01m50s,SCREEN_MATCHING
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,02m09s,SCREEN_REQ_TIMEOUT
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,02m27s,SCREEN_MATCHING
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,02m47s,SCREEN_NO_MATCH
# cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087,03m04s,SCREEN_MATCHING
# ==018==
# cn-t1-05-01_3121_20180718041101.wav_sub_3311_3365,00m05s,SCREEN_NO_MATCH
# cn-t1-05-01_3121_20180718041101.wav_sub_3311_3365,00m20s,SCREEN_MATCHUP_EXTRACT_DONE,偶遇,偶遇,王菲
# cn-t1-05-01_3121_20180718041101.wav_sub_3311_3365,00m48s,SCREEN_MATCHUP_EXTRACT_DONE,偶遇,偶遇,王菲
# ==019==
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,00m59s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,01m25s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,01m54s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,02m21s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,02m48s,SCREEN_MATCHUP_EXTRACT_DONE,′'′霞  飞飞,麟   富亳… 薯誓青二',杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,03m16s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,03m45s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,04m13s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,04m40s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,05m09s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,05m36s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,06m03s,SCREEN_MATCHING
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,06m22s,SCREEN_MATCHUP_EXTRACT_DONE,甜姐辣妹,甜姐辣妹,许玮宁/姚安琪
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,06m49s,SCREEN_MATCHING
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,07m09s,SCREEN_MATCHUP_EXTRACT_DONE,爱你呦,爱你呦,小雅/杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,07m36s,SCREEN_MATCHUP_EXTRACT_DONE,爱你呦,爱你呦,小雅/杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,08m03s,SCREEN_MATCHUP_EXTRACT_DONE,爱你呦,爱你呦,小雅/杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,08m30s,SCREEN_MATCHUP_EXTRACT_DONE,爱你哟,爱你哟,小雅/杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,08m57s,SCREEN_MATCHUP_EXTRACT_DONE,爱你呦,爱你呦,小雅/杨家成
# cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988,09m23s,SCREEN_MATCHUP_EXTRACT_DONE,爱你呦,爱你呦,小雅/杨家成
# ==020==
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,00m34s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,01m01s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,01m28s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,01m57s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,02m24s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,02m50s,SCREEN_MATCHUP_EXTRACT_DONE,你的好,你的好,林采欣
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,03m17s,SCREEN_MATCHING
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,03m36s,SCREEN_NO_MATCH
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,03m52s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,04m19s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,04m45s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,05m11s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,05m39s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,06m05s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735,06m33s,SCREEN_MATCHUP_EXTRACT_DONE,快乐星球,快乐星球,/J、雅
# ==021==
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,00m05s,SCREEN_MATCHING
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,00m26s,SCREEN_NO_MATCH
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,00m41s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,01m08s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,01m36s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,02m03s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,02m30s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# cn-t1-05-01_3125_20180718081101.wav_sub_678_857,02m56s,SCREEN_MATCHUP_EXTRACT_DONE,心仍  曰\〈 天E/7,心仍罡冷,杨千婵
# ==022==
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,00m05s,SCREEN_MATCHING
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,00m25s,SCREEN_MATCHUP_EXTRACT_DONE,好想说爱你,好想说爱你,燕俊霆
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,00m55s,SCREEN_MATCHUP_EXTRACT_DONE,配角,配角,顾海滨
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,01m21s,SCREEN_MATCHUP_EXTRACT_DONE,配角,配角,顾海滨
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,01m47s,SCREEN_MATCHUP_EXTRACT_DONE,配角,配角,顾海滨
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,02m14s,SCREEN_MATCHUP_EXTRACT_DONE,配角 (伴奏),配角 (伴奏),顾海滨
# cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677,02m40s,SCREEN_MATCHUP_EXTRACT_DONE,配角,配角,顾海滨
# ==023==
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,00m31s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,00m58s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,01m25s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,01m52s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,02m20s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360,02m47s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# ==024==
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,00m05s,SCREEN_MATCHING
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,00m25s,SCREEN_NO_MATCH
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,00m40s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,01m09s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,01m37s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,02m05s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,02m33s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408,03m01s,SCREEN_MATCHUP_EXTRACT_DONE,闪壳的魔法,闪壳的魔法,周笔畅
# ==025==
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,00m58s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,01m24s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,01m50s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,02m16s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# cn-t1-06-01_3098_20180717081101.wav_sub_945_1125,02m43s,SCREEN_MATCHUP_EXTRACT_DONE,需要你的爱,需要你的爱,飞儿乐团/信
# ==026==
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,00m59s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,01m26s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,01m52s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,02m17s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855,02m45s,SCREEN_MATCHUP_EXTRACT_DONE,知道不知道,知道不知道,胡夏
# ==027==
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,00m05s,SCREEN_MATCHING
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,00m25s,SCREEN_NO_MATCH
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,00m41s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,告别,黄大炜
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,01m06s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,告别,黄大炜
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,01m33s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,告别,黄大炜
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,01m58s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,告别,黄大炜
# cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396,02m24s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,告别,黄大炜
# ==028==
# cn-t1-07-01_3091_20180717011103.wav_sub_2573_2603,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-07-01_3091_20180717011103.wav_sub_2573_2603,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,贵钞 \卜_ 方 言,贵州 方言,王羽
# ==029==
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,00m05s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,00m24s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,00m40s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,01m00s,SCREEN_MATCHUP_EXTRACT_DONE,开往锡城的火车,开往锡城的火车,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,01m26s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,01m46s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,02m01s,SCREEN_MATCHUP_EXTRACT_DONE,开往锡城的火车,开往锡城的火车,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,02m27s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,02m48s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,03m04s,SCREEN_MATCHUP_EXTRACT_DONE,开往锡城的火车,开往锡城的火车,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,03m30s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,03m49s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,04m05s,SCREEN_MATCHUP_EXTRACT_DONE,开往锡城的火车,开往锡城的火车,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,04m32s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,04m53s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,05m09s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,05m29s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,05m44s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,06m04s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,06m19s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,06m39s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,06m53s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,07m13s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,07m28s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,07m49s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,08m05s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,08m25s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,08m42s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,09m02s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,09m31s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,10m00s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,10m26s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,10m53s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,11m20s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,11m46s,SCREEN_MATCHUP_EXTRACT_DONE,木头人,木头人,徐艺伦
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,12m13s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,12m32s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,12m47s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,13m08s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,13m23s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,13m43s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,13m58s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,14m18s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,14m34s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,14m53s,SCREEN_NO_MATCH
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,15m09s,SCREEN_MATCHING
# cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747,15m28s,SCREEN_NO_MATCH
# ==030==
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,01m00s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,01m26s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,01m52s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,02m18s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# cn-t1-07-01_3106_20180717154141.wav_sub_35_197,02m46s,SCREEN_MATCHUP_EXTRACT_DONE,_场雨落下来要用 多久,_场雨落下来要用 多久,鹿先森乐队
# ==031==
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,00m33s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,01m02s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,01m29s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,01m56s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,02m22s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# cn-t1-07-01_3118_20180718011101.wav_sub_893_1061,02m51s,SCREEN_MATCHUP_EXTRACT_DONE,Tango Azul,Tango Azul,Guitarra AZu_
# ==032==
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,00m35s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,01m01s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,01m30s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,01m56s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,02m23s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991,02m52s,SCREEN_MATCHUP_EXTRACT_DONE,背后女人,背后女人,杨千婵/周柏熹
# ==033==
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,00m05s,SCREEN_MATCHING
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,00m26s,SCREEN_NO_MATCH
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,00m41s,SCREEN_MATCHING
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,01m01s,SCREEN_NO_MATCH
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,01m17s,SCREEN_MATCHING
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,01m37s,SCREEN_NO_MATCH
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,01m52s,SCREEN_MATCHING
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,02m12s,SCREEN_NO_MATCH
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,02m27s,SCREEN_MATCHING
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,02m47s,SCREEN_NO_MATCH
# cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214,03m02s,SCREEN_MATCHING
# ==034==
# cn-t1-08-01_3084_20180716181101.wav_sub_3173_3179,00m05s,SCREEN_NO_MATCH
# ==035==
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,00m33s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,那英/ 张惠妹/林忆莲/蔡健雅
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,01m02s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,那英/ 张惠妹/林忆莲/蔡健雅
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,01m31s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,那英/ 张惠妹/林忆莲/蔡健雅
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,02m01s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,那英/ 张惠妹/林忆莲/蔡健雅
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,02m29s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,华语群星
# cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258,02m56s,SCREEN_MATCHUP_EXTRACT_DONE,We Are One,We Are One,华语群星
# ==036==
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,00m58s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,01m23s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,01m49s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,02m16s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439,02m41s,SCREEN_MATCHUP_EXTRACT_DONE,When _ Was Your Man,When _ Was Your Man,一 Sam Smith —
# ==037==
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,给力胃春,给力胃春,群星
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,00m58s,SCREEN_MATCHUP_EXTRACT_DONE,给力胃春,给力胃春,群星
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,01m25s,SCREEN_MATCHUP_EXTRACT_DONE,给力胃春,给力胃春,群星
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,01m52s,SCREEN_MATCHUP_EXTRACT_DONE,给力胃春,给力胃春,群星
# cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343,02m19s,SCREEN_MATCHUP_EXTRACT_DONE,给力胃春,给力胃春,群星
# ==038==
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,01m03s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,01m32s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,01m58s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,02m24s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817,02m51s,SCREEN_MATCHUP_EXTRACT_DONE,| Lomo You (Demo),| Lomo You (Demo),GALA
# ==039==
# cn-t1-08-01_3125_20180718081101.wav_sub_3146_3170,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# ==040==
# cnn-01_3084_20180716181100.wav_sub_1874_2054,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-01_3084_20180716181100.wav_sub_1874_2054,00m30s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_1874_2054,00m49s,SCREEN_MATCHUP_EXTRACT_DONE,哪里哪里,哪里哪里,叶柔
# cnn-01_3084_20180716181100.wav_sub_1874_2054,01m17s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,,° C? ...,
# cnn-01_3084_20180716181100.wav_sub_1874_2054,01m42s,SCREEN_MATCHUP_EXTRACT_DONE,哪里哪里,哪里哪里,叶柔
# cnn-01_3084_20180716181100.wav_sub_1874_2054,02m09s,SCREEN_MATCHUP_EXTRACT_DONE,哪里哪里,哪里哪里,叶柔
# cnn-01_3084_20180716181100.wav_sub_1874_2054,02m36s,SCREEN_MATCHUP_EXTRACT_DONE,哪里哪里,哪里哪里,叶柔
# cnn-01_3084_20180716181100.wav_sub_1874_2054,03m03s,SCREEN_MATCHUP_EXTRACT_DONE,哪里哪里,哪里哪里,叶柔
# ==041==
# cnn-01_3084_20180716181100.wav_sub_522_701,00m05s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_522_701,00m24s,SCREEN_NO_MATCH
# cnn-01_3084_20180716181100.wav_sub_522_701,00m40s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_522_701,00m59s,SCREEN_NO_MATCH
# cnn-01_3084_20180716181100.wav_sub_522_701,01m14s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_522_701,01m35s,SCREEN_NO_MATCH
# cnn-01_3084_20180716181100.wav_sub_522_701,01m50s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_522_701,02m10s,SCREEN_NO_MATCH
# cnn-01_3084_20180716181100.wav_sub_522_701,02m25s,SCREEN_MATCHING
# cnn-01_3084_20180716181100.wav_sub_522_701,02m46s,SCREEN_NO_MATCH
# cnn-01_3084_20180716181100.wav_sub_522_701,03m01s,SCREEN_MATCHING
# ==042==
# cnn-01_3085_20180716191101.wav_sub_596_740,00m05s,SCREEN_NO_MATCH
# cnn-01_3085_20180716191101.wav_sub_596_740,00m21s,SCREEN_MATCHUP_EXTRACT_DONE,敲内脑,敲内脑,陈萝莉
# cnn-01_3085_20180716191101.wav_sub_596_740,00m47s,SCREEN_MATCHUP_EXTRACT_DONE,敲内脑,敲内脑,陈萝莉
# cnn-01_3085_20180716191101.wav_sub_596_740,01m14s,SCREEN_MATCHUP_EXTRACT_DONE,敲内脑,敲内脑,陈萝莉
# cnn-01_3085_20180716191101.wav_sub_596_740,01m39s,SCREEN_MATCHUP_EXTRACT_DONE,敲内脑,敲内脑,陈萝莉
# cnn-01_3085_20180716191101.wav_sub_596_740,02m07s,SCREEN_MATCHUP_EXTRACT_DONE,敲内脑,敲内脑,陈萝莉
# ==043==
# cnn-01_3093_20180717031101.wav_sub_444_623,00m05s,SCREEN_MATCHING
# cnn-01_3093_20180717031101.wav_sub_444_623,00m24s,SCREEN_NO_MATCH
# cnn-01_3093_20180717031101.wav_sub_444_623,00m40s,SCREEN_MATCHING
# cnn-01_3093_20180717031101.wav_sub_444_623,01m00s,SCREEN_NO_MATCH
# cnn-01_3093_20180717031101.wav_sub_444_623,01m15s,SCREEN_MATCHING
# cnn-01_3093_20180717031101.wav_sub_444_623,01m35s,SCREEN_NO_MATCH
# cnn-01_3093_20180717031101.wav_sub_444_623,01m50s,SCREEN_MATCHING
# cnn-01_3093_20180717031101.wav_sub_444_623,02m10s,SCREEN_NO_MATCH
# cnn-01_3093_20180717031101.wav_sub_444_623,02m25s,SCREEN_MATCHING
# cnn-01_3093_20180717031101.wav_sub_444_623,02m46s,SCREEN_NO_MATCH
# cnn-01_3093_20180717031101.wav_sub_444_623,03m03s,SCREEN_MATCHING
# ==044==
# cnn-01_3096_20180717061100.wav_sub_1460_1598,00m06s,SCREEN_NO_MATCH
# cnn-01_3096_20180717061100.wav_sub_1460_1598,00m21s,SCREEN_MATCHUP_EXTRACT_DONE,不准你走,不准你走,钟镇涛
# cnn-01_3096_20180717061100.wav_sub_1460_1598,00m48s,SCREEN_MATCHUP_EXTRACT_DONE,不准你走,不准你走,钟镇涛
# cnn-01_3096_20180717061100.wav_sub_1460_1598,01m16s,SCREEN_MATCHUP_EXTRACT_DONE,不准你走,不准你走,钟镇涛
# cnn-01_3096_20180717061100.wav_sub_1460_1598,01m43s,SCREEN_MATCHUP_EXTRACT_DONE,不准你走,不准你走,钟镇涛
# cnn-01_3096_20180717061100.wav_sub_1460_1598,02m13s,SCREEN_MATCHUP_EXTRACT_DONE,不准你走,不准你走,钟镇涛
# ==045==
# cnn-01_3098_20180717081100.wav_sub_2613_2792,00m05s,SCREEN_MATCHING
# cnn-01_3098_20180717081100.wav_sub_2613_2792,00m24s,SCREEN_NO_MATCH
# cnn-01_3098_20180717081100.wav_sub_2613_2792,00m40s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,刘晶/阎维文
# cnn-01_3098_20180717081100.wav_sub_2613_2792,01m08s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,阎维文/刘晶
# cnn-01_3098_20180717081100.wav_sub_2613_2792,01m35s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,刘晶/阎维文
# cnn-01_3098_20180717081100.wav_sub_2613_2792,02m03s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,刘晶/阎维文
# cnn-01_3098_20180717081100.wav_sub_2613_2792,02m30s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,刘晶/阎维文
# cnn-01_3098_20180717081100.wav_sub_2613_2792,02m57s,SCREEN_MATCHUP_EXTRACT_DONE,共圆中国梦,共圆中国梦,刘晶/阎维文
# ==046==
# cnn-01_3106_20180717154139.wav_sub_2346_2525,00m05s,SCREEN_MATCHING
# cnn-01_3106_20180717154139.wav_sub_2346_2525,00m26s,SCREEN_NO_MATCH
# cnn-01_3106_20180717154139.wav_sub_2346_2525,00m41s,SCREEN_MATCHING
# cnn-01_3106_20180717154139.wav_sub_2346_2525,01m02s,SCREEN_NO_MATCH
# cnn-01_3106_20180717154139.wav_sub_2346_2525,01m17s,SCREEN_MATCHING
# cnn-01_3106_20180717154139.wav_sub_2346_2525,01m37s,SCREEN_NO_MATCH
# cnn-01_3106_20180717154139.wav_sub_2346_2525,01m53s,SCREEN_MATCHING
# cnn-01_3106_20180717154139.wav_sub_2346_2525,02m15s,SCREEN_NO_MATCH
# cnn-01_3106_20180717154139.wav_sub_2346_2525,02m31s,SCREEN_MATCHING
# cnn-01_3106_20180717154139.wav_sub_2346_2525,02m54s,SCREEN_NO_MATCH
# ==047==
# cnn-01_3120_20180718031101.wav_sub_2237_2375,00m05s,SCREEN_MATCHING
# cnn-01_3120_20180718031101.wav_sub_2237_2375,00m27s,SCREEN_MATCHUP_EXTRACT_DONE,The Passenger,The Passenger,Lady Ha Ha
# cnn-01_3120_20180718031101.wav_sub_2237_2375,00m55s,SCREEN_MATCHING
# cnn-01_3120_20180718031101.wav_sub_2237_2375,01m16s,SCREEN_NO_MATCH
# cnn-01_3120_20180718031101.wav_sub_2237_2375,01m34s,SCREEN_MATCHING
# cnn-01_3120_20180718031101.wav_sub_2237_2375,01m55s,SCREEN_NO_MATCH
# cnn-01_3120_20180718031101.wav_sub_2237_2375,02m11s,SCREEN_MATCHING
# ==048==
# cnn-01_3125_20180718081101.wav_sub_2652_2831,00m05s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_2652_2831,00m21s,SCREEN_MATCHUP_EXTRACT_DONE,爱国歌,爱国歌,喻越越/蔡鹏
# cnn-01_3125_20180718081101.wav_sub_2652_2831,00m48s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_2652_2831,01m08s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_2652_2831,01m23s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_2652_2831,01m42s,SCREEN_MATCHUP_EXTRACT_DONE,爱国歌,爱国歌,喻越越/蔡鹏
# cnn-01_3125_20180718081101.wav_sub_2652_2831,02m10s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_2652_2831,02m30s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_2652_2831,02m45s,SCREEN_MATCHUP_EXTRACT_DONE,爱国歌,爱国歌,喻越越/蔡鹏
# ==049==
# cnn-01_3125_20180718081101.wav_sub_591_770,00m05s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_591_770,00m28s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_591_770,00m44s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,蜜语&for 热娜,蜜语&for 热娜,
# cnn-01_3125_20180718081101.wav_sub_591_770,01m13s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_591_770,01m36s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_591_770,01m53s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_591_770,02m15s,SCREEN_NO_MATCH
# cnn-01_3125_20180718081101.wav_sub_591_770,02m30s,SCREEN_MATCHING
# cnn-01_3125_20180718081101.wav_sub_591_770,02m50s,SCREEN_NO_MATCH
# ==050==
# cnn-02_3097_20180717071101.wav_sub_1236_1415,00m05s,SCREEN_MATCHING
# cnn-02_3097_20180717071101.wav_sub_1236_1415,00m25s,SCREEN_NO_MATCH
# cnn-02_3097_20180717071101.wav_sub_1236_1415,00m41s,SCREEN_MATCHING
# cnn-02_3097_20180717071101.wav_sub_1236_1415,01m01s,SCREEN_NO_MATCH
# cnn-02_3097_20180717071101.wav_sub_1236_1415,01m18s,SCREEN_MATCHING
# cnn-02_3097_20180717071101.wav_sub_1236_1415,01m38s,SCREEN_NO_MATCH
# cnn-02_3097_20180717071101.wav_sub_1236_1415,01m54s,SCREEN_MATCHUP_EXTRACT_DONE,Daylight (With You) (Vocal Version),Daylight (With You) (Vocal Version),Yves V/Dimitri Vangelis & Wyman
# cnn-02_3097_20180717071101.wav_sub_1236_1415,02m20s,SCREEN_MATCHING
# cnn-02_3097_20180717071101.wav_sub_1236_1415,02m41s,SCREEN_NO_MATCH
# cnn-02_3097_20180717071101.wav_sub_1236_1415,02m57s,SCREEN_MATCHING
# ==051==
# cnn-02_3098_20180717081101.wav_sub_1158_1535,00m05s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_1158_1535,00m21s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_1158_1535,00m41s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_1158_1535,00m56s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_1158_1535,01m16s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_1158_1535,01m31s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_1158_1535,01m51s,SCREEN_MATCHUP_EXTRACT_DONE,Jenny E' Pazza,Jenny E' Pazza,Vasco Rossi
# cnn-02_3098_20180717081101.wav_sub_1158_1535,02m18s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_1158_1535,02m38s,SCREEN_MATCHUP_EXTRACT_DONE,The Train That Never Came,The Train That Never Came,一 Willie McBIind —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,03m06s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL|SCREEN_MATCHUP_EXTRACT_TRACK_PSM7_FAIL|SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,,,
# cnn-02_3098_20180717081101.wav_sub_1158_1535,03m32s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,03m58s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,04m24s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,04m50s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,05m16s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,05m41s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# cnn-02_3098_20180717081101.wav_sub_1158_1535,06m08s,SCREEN_MATCHUP_EXTRACT_DONE,Heart Speak (Dzeko vs. Waves Remix),Heart Speak (Dzeko vs. Waves Remix),一 Dzeko/TO KA-J —
# ==052==
# cnn-02_3098_20180717081101.wav_sub_2258_2438,00m05s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_2258_2438,00m25s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_2258_2438,00m40s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_2258_2438,00m59s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_2258_2438,01m15s,SCREEN_MATCHUP_EXTRACT_DONE,枫宇辰电音 (DJ片反),枫宇辰电音 (DJ片反),枫宇辰/六月/DJ马哥
# cnn-02_3098_20180717081101.wav_sub_2258_2438,01m41s,SCREEN_MATCHUP_EXTRACT_DONE,Legion (Original Mix),Legion (Original Mix),Madsoul
# cnn-02_3098_20180717081101.wav_sub_2258_2438,02m07s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_2258_2438,02m27s,SCREEN_NO_MATCH
# cnn-02_3098_20180717081101.wav_sub_2258_2438,02m43s,SCREEN_MATCHING
# cnn-02_3098_20180717081101.wav_sub_2258_2438,03m03s,SCREEN_NO_MATCH
# ==053==
# cnn-02_3124_20180718071101.wav_sub_1463_1781,00m06s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,00m25s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,00m40s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,01m01s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,01m16s,SCREEN_MATCHUP_EXTRACT_DONE,Geil 2K11(Andy LaToggo Remix) (Remix),Geil 2K11(Andy LaToggo Remix) (Remix),一 TMB Crew —
# cnn-02_3124_20180718071101.wav_sub_1463_1781,01m43s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,02m03s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,02m18s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,02m39s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,02m54s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,03m14s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,03m30s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,03m50s,SCREEN_MATCHUP_EXTRACT_DONE,Evergreen,Evergreen,— GENERATIONS from EXILE TRIBE (放浪新世代 from 放浪_族) 一
# cnn-02_3124_20180718071101.wav_sub_1463_1781,04m18s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,04m38s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_1463_1781,04m53s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_1463_1781,05m15s,SCREEN_NO_MATCH
# ==054==
# cnn-02_3124_20180718071101.wav_sub_2381_2399,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# ==055==
# cnn-02_3124_20180718071101.wav_sub_962_1250,00m05s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,00m26s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,00m41s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,01m01s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,01m16s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,01m36s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,01m52s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,02m14s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,02m30s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,02m52s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,03m08s,SCREEN_MATCHUP_EXTRACT_DONE,爱情天秤,爱情天秤,浅宇熙
# cnn-02_3124_20180718071101.wav_sub_962_1250,03m40s,SCREEN_MATCHUP_EXTRACT_DONE,坐标快手 (DJ片反),坐标快手 (DJ片反),MC赵小涣
# cnn-02_3124_20180718071101.wav_sub_962_1250,04m10s,SCREEN_MATCHING
# cnn-02_3124_20180718071101.wav_sub_962_1250,04m30s,SCREEN_NO_MATCH
# cnn-02_3124_20180718071101.wav_sub_962_1250,04m45s,SCREEN_MATCHING
# ==056==
# cnn-07_3084_20180716181101.wav_sub_3099_3237,00m05s,SCREEN_NO_MATCH
# cnn-07_3084_20180716181101.wav_sub_3099_3237,00m20s,SCREEN_MATCHING
# cnn-07_3084_20180716181101.wav_sub_3099_3237,00m40s,SCREEN_NO_MATCH
# cnn-07_3084_20180716181101.wav_sub_3099_3237,00m56s,SCREEN_MATCHING
# cnn-07_3084_20180716181101.wav_sub_3099_3237,01m16s,SCREEN_NO_MATCH
# cnn-07_3084_20180716181101.wav_sub_3099_3237,01m31s,SCREEN_MATCHING
# cnn-07_3084_20180716181101.wav_sub_3099_3237,01m50s,SCREEN_NO_MATCH
# cnn-07_3084_20180716181101.wav_sub_3099_3237,02m06s,SCREEN_MATCHING
# ==057==
# cnn-07_3085_20180716191101.wav_sub_1737_2121,00m05s,SCREEN_NO_MATCH
# cnn-07_3085_20180716191101.wav_sub_1737_2121,00m21s,SCREEN_MATCHUP_EXTRACT_DONE,葡萄园夜曲,葡萄园夜曲,一 丁iankong合唱团 —
# cnn-07_3085_20180716191101.wav_sub_1737_2121,00m50s,SCREEN_MATCHUP_EXTRACT_DONE,葡萄园夜曲,葡萄园夜曲,一 丁iankong合唱团 —
# cnn-07_3085_20180716191101.wav_sub_1737_2121,01m19s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_1737_2121,01m38s,SCREEN_NO_MATCH
# cnn-07_3085_20180716191101.wav_sub_1737_2121,01m54s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,02m22s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,02m51s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,03m20s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,03m49s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,04m17s,SCREEN_MATCHUP_EXTRACT_DONE,有 _个美丽的地方,有 _个美丽的地方,Various Artists
# cnn-07_3085_20180716191101.wav_sub_1737_2121,04m45s,SCREEN_MATCHUP_EXTRACT_DONE,黑眼睛小驼糕,黑眼睛小驼糕,哈王林
# cnn-07_3085_20180716191101.wav_sub_1737_2121,05m13s,SCREEN_MATCHUP_EXTRACT_DONE,黑眼睛小驼糕,黑眼睛小驼糕,哈王林
# cnn-07_3085_20180716191101.wav_sub_1737_2121,05m41s,SCREEN_MATCHUP_EXTRACT_DONE,黑眼睛小驼糕,黑眼睛小驼糕,哈王林
# cnn-07_3085_20180716191101.wav_sub_1737_2121,06m09s,SCREEN_MATCHUP_EXTRACT_DONE,黑眼睛小驼糕,黑眼睛小驼糕,哈王林
# ==058==
# cnn-07_3085_20180716191101.wav_sub_699_879,00m05s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_699_879,00m25s,SCREEN_MATCHUP_EXTRACT_DONE,闹五更,闹五更,亚星
# cnn-07_3085_20180716191101.wav_sub_699_879,00m51s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_699_879,01m11s,SCREEN_NO_MATCH
# cnn-07_3085_20180716191101.wav_sub_699_879,01m26s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_699_879,01m46s,SCREEN_NO_MATCH
# cnn-07_3085_20180716191101.wav_sub_699_879,02m01s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_699_879,02m23s,SCREEN_NO_MATCH
# cnn-07_3085_20180716191101.wav_sub_699_879,02m39s,SCREEN_MATCHING
# cnn-07_3085_20180716191101.wav_sub_699_879,02m59s,SCREEN_NO_MATCH
# ==059==
# cnn-07_3087_20180716211101.wav_sub_2253_2433,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3087_20180716211101.wav_sub_2253_2433,00m32s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# cnn-07_3087_20180716211101.wav_sub_2253_2433,01m00s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# cnn-07_3087_20180716211101.wav_sub_2253_2433,01m27s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# cnn-07_3087_20180716211101.wav_sub_2253_2433,01m55s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# cnn-07_3087_20180716211101.wav_sub_2253_2433,02m22s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# cnn-07_3087_20180716211101.wav_sub_2253_2433,02m50s,SCREEN_MATCHUP_EXTRACT_DONE,峨眉山月歌,峨眉山月歌,盛中国
# ==060==
# cnn-07_3087_20180716211101.wav_sub_414_1104,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3087_20180716211101.wav_sub_414_1104,00m33s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,01m01s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,01m29s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,01m57s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,02m25s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,02m53s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,03m22s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,03m50s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,04m18s,SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL,,康定情歌与溜溜调 (Live),谭维维
# cnn-07_3087_20180716211101.wav_sub_414_1104,04m47s,SCREEN_MATCHING
# cnn-07_3087_20180716211101.wav_sub_414_1104,05m06s,SCREEN_NO_MATCH
# cnn-07_3087_20180716211101.wav_sub_414_1104,05m21s,SCREEN_MATCHING
# cnn-07_3087_20180716211101.wav_sub_414_1104,05m42s,SCREEN_NO_MATCH
# cnn-07_3087_20180716211101.wav_sub_414_1104,05m58s,SCREEN_MATCHING
# cnn-07_3087_20180716211101.wav_sub_414_1104,06m17s,SCREEN_NO_MATCH
# cnn-07_3087_20180716211101.wav_sub_414_1104,06m33s,SCREEN_MATCHING
# cnn-07_3087_20180716211101.wav_sub_414_1104,06m53s,SCREEN_NO_MATCH
# cnn-07_3087_20180716211101.wav_sub_414_1104,07m08s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,07m35s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,08m02s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,08m29s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,08m58s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,09m25s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,09m55s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,好想再爱你,好想再爱你,
# cnn-07_3087_20180716211101.wav_sub_414_1104,10m21s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,10m48s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# cnn-07_3087_20180716211101.wav_sub_414_1104,11m15s,SCREEN_MATCHUP_EXTRACT_DONE,′_`…肖… 3*" /两康 定,情满康定,李志辉
# ==061==
# cnn-07_3094_20180717041101.wav_sub_1494_1674,00m05s,SCREEN_MATCHING
# cnn-07_3094_20180717041101.wav_sub_1494_1674,00m26s,SCREEN_NO_MATCH
# cnn-07_3094_20180717041101.wav_sub_1494_1674,00m42s,SCREEN_MATCHING
# cnn-07_3094_20180717041101.wav_sub_1494_1674,01m01s,SCREEN_NO_MATCH
# cnn-07_3094_20180717041101.wav_sub_1494_1674,01m17s,SCREEN_MATCHING
# cnn-07_3094_20180717041101.wav_sub_1494_1674,01m39s,SCREEN_NO_MATCH
# cnn-07_3094_20180717041101.wav_sub_1494_1674,01m55s,SCREEN_MATCHING
# cnn-07_3094_20180717041101.wav_sub_1494_1674,02m14s,SCREEN_NO_MATCH
# cnn-07_3094_20180717041101.wav_sub_1494_1674,02m30s,SCREEN_MATCHING
# cnn-07_3094_20180717041101.wav_sub_1494_1674,02m49s,SCREEN_NO_MATCH
# ==062==
# cnn-07_3095_20180717051101.wav_sub_2655_2835,00m05s,SCREEN_MATCHING
# cnn-07_3095_20180717051101.wav_sub_2655_2835,00m25s,SCREEN_NO_MATCH
# cnn-07_3095_20180717051101.wav_sub_2655_2835,00m40s,SCREEN_MATCHING
# cnn-07_3095_20180717051101.wav_sub_2655_2835,01m03s,SCREEN_NO_MATCH
# cnn-07_3095_20180717051101.wav_sub_2655_2835,01m18s,SCREEN_MATCHING
# cnn-07_3095_20180717051101.wav_sub_2655_2835,01m38s,SCREEN_NO_MATCH
# cnn-07_3095_20180717051101.wav_sub_2655_2835,01m54s,SCREEN_MATCHING
# cnn-07_3095_20180717051101.wav_sub_2655_2835,02m14s,SCREEN_NO_MATCH
# cnn-07_3095_20180717051101.wav_sub_2655_2835,02m31s,SCREEN_MATCHING
# cnn-07_3095_20180717051101.wav_sub_2655_2835,02m53s,SCREEN_NO_MATCH
# ==063==
# cnn-07_3096_20180717061101.wav_sub_2148_2328,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3096_20180717061101.wav_sub_2148_2328,00m34s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# cnn-07_3096_20180717061101.wav_sub_2148_2328,01m00s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# cnn-07_3096_20180717061101.wav_sub_2148_2328,01m26s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# cnn-07_3096_20180717061101.wav_sub_2148_2328,01m53s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# cnn-07_3096_20180717061101.wav_sub_2148_2328,02m20s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# cnn-07_3096_20180717061101.wav_sub_2148_2328,02m47s,SCREEN_MATCHUP_EXTRACT_DONE,Monica (Live),Monica (Live),古巨墓
# ==064==
# cnn-07_3098_20180717081101.wav_sub_1386_1566,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3098_20180717081101.wav_sub_1386_1566,00m38s,SCREEN_MATCHUP_EXTRACT_DONE,"Don Giovanni′ K.527 / ACt1 - Madamina, il catalogo é questo (亲爱的天人呀， 这就罡名 单)",ca邑宇藿g冒i亘V写…写墓壬薯鬓鬟'白含昊又蹭a霆蛊逞a名i革),一 Teddy Tahu Rhodes/Tasmanian Symphony Orchestra/Ola Rudner —
# cnn-07_3098_20180717081101.wav_sub_1386_1566,01m13s,SCREEN_MATCHUP_EXTRACT_DONE,"Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)",Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 ",Classical Artists
# cnn-07_3098_20180717081101.wav_sub_1386_1566,01m44s,SCREEN_MATCHUP_EXTRACT_DONE,"Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)",Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 ",Classical Artists
# cnn-07_3098_20180717081101.wav_sub_1386_1566,02m16s,SCREEN_MATCHUP_EXTRACT_DONE,"Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)",Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 ",Classical Artists
# cnn-07_3098_20180717081101.wav_sub_1386_1566,02m48s,SCREEN_MATCHUP_EXTRACT_DONE,"Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)",Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 ",Classical Artists
# ==065==
# cnn-07_3098_20180717081101.wav_sub_2373_2739,00m05s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,00m24s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,00m40s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,01m00s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,01m15s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,01m36s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,01m51s,SCREEN_MATCHUP_EXTRACT_DONE,"Piano Concerto No. 21 in C major, K. 467 — Andante","Piano Concerto hrﬁd2a1nigc major, K. 467 —",Yu Kosuge (/J、菅 1蔓)
# cnn-07_3098_20180717081101.wav_sub_2373_2739,02m19s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,02m39s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,02m54s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,03m14s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,03m29s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,03m49s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,04m05s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,04m24s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,04m40s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,05m00s,SCREEN_NO_MATCH
# cnn-07_3098_20180717081101.wav_sub_2373_2739,05m15s,SCREEN_MATCHUP_EXTRACT_DONE,Felicidad,Felicidad,一 Monjes Budistas —
# cnn-07_3098_20180717081101.wav_sub_2373_2739,05m43s,SCREEN_MATCHING
# cnn-07_3098_20180717081101.wav_sub_2373_2739,06m03s,SCREEN_NO_MATCH
# ==066==
# cnn-07_3110_20180717191101.wav_sub_2040_2220,00m05s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_2040_2220,00m26s,SCREEN_MATCHUP_EXTRACT_DONE,蒙古人,蒙古人,Various Artists
# cnn-07_3110_20180717191101.wav_sub_2040_2220,00m52s,SCREEN_MATCHUP_EXTRACT_DONE,蒙古人,蒙古人,Various Artists
# cnn-07_3110_20180717191101.wav_sub_2040_2220,01m18s,SCREEN_MATCHUP_EXTRACT_DONE,"Toccata Quinta In G Major "Per L'organo Sopta | Pedali, e Senza"",Toccata Quinta 曾e冒a惚′a卓O卓墓言室戛搜O「ganO Sopta |,Fernando Germani
# cnn-07_3110_20180717191101.wav_sub_2040_2220,01m47s,SCREEN_MATCHUP_EXTRACT_DONE,蒙古人,蒙古人,Various Artists
# cnn-07_3110_20180717191101.wav_sub_2040_2220,02m14s,SCREEN_MATCHUP_EXTRACT_DONE,蒙古人,蒙古人,Various Artists
# cnn-07_3110_20180717191101.wav_sub_2040_2220,02m41s,SCREEN_MATCHUP_EXTRACT_DONE,蒙古人,蒙古人,Various Artists
# ==067==
# cnn-07_3110_20180717191101.wav_sub_2649_2805,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3110_20180717191101.wav_sub_2649_2805,00m34s,SCREEN_MATCHUP_EXTRACT_DONE,新编阿里郎,新编阿里郎,金皇
# cnn-07_3110_20180717191101.wav_sub_2649_2805,01m04s,SCREEN_MATCHUP_EXTRACT_DONE,新编阿里郎,新编阿里郎,金皇
# cnn-07_3110_20180717191101.wav_sub_2649_2805,01m32s,SCREEN_MATCHUP_EXTRACT_DONE,新编阿里郎,新编阿里郎,金皇
# cnn-07_3110_20180717191101.wav_sub_2649_2805,01m59s,SCREEN_MATCHUP_EXTRACT_DONE,新编阿里郎,新编阿里郎,金皇
# cnn-07_3110_20180717191101.wav_sub_2649_2805,02m28s,SCREEN_MATCHUP_EXTRACT_DONE,新编阿里郎,新编阿里郎,金皇
# ==068==
# cnn-07_3110_20180717191101.wav_sub_969_1617,00m05s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_969_1617,00m26s,SCREEN_NO_MATCH
# cnn-07_3110_20180717191101.wav_sub_969_1617,00m41s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,01m08s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,01m35s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,02m02s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,02m30s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,02m56s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,03m22s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,03m49s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,04m16s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,04m45s,SCREEN_MATCHUP_EXTRACT_DONE,重逢,重逢,常石磊/马上又/袁娅维/李佳
# cnn-07_3110_20180717191101.wav_sub_969_1617,05m13s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_969_1617,05m36s,SCREEN_NO_MATCH
# cnn-07_3110_20180717191101.wav_sub_969_1617,05m52s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_969_1617,06m11s,SCREEN_NO_MATCH
# cnn-07_3110_20180717191101.wav_sub_969_1617,06m27s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_969_1617,06m46s,SCREEN_NO_MATCH
# cnn-07_3110_20180717191101.wav_sub_969_1617,07m03s,SCREEN_MATCHING
# cnn-07_3110_20180717191101.wav_sub_969_1617,07m25s,SCREEN_NO_MATCH
# cnn-07_3110_20180717191101.wav_sub_969_1617,07m40s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,08m07s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,08m36s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,09m03s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,09m30s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,09m56s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,10m22s,SCREEN_MATCHUP_EXTRACT_DONE,江南,江南,喻越越/杨鸿年少年合唱团
# cnn-07_3110_20180717191101.wav_sub_969_1617,10m52s,SCREEN_MATCHUP_EXTRACT_DONE,四季的问候,四季的问候,上海小荧星合唱团
# ==069==
# cnn-07_3117_20180718003124.wav_sub_3213_3393,00m05s,SCREEN_MATCHING
# cnn-07_3117_20180718003124.wav_sub_3213_3393,00m28s,SCREEN_NO_MATCH
# cnn-07_3117_20180718003124.wav_sub_3213_3393,00m44s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3117_20180718003124.wav_sub_3213_3393,01m09s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3117_20180718003124.wav_sub_3213_3393,01m35s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3117_20180718003124.wav_sub_3213_3393,02m00s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3117_20180718003124.wav_sub_3213_3393,02m26s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3117_20180718003124.wav_sub_3213_3393,02m52s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# ==070==
# cnn-07_3117_20180718003124.wav_sub_690_912,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3117_20180718003124.wav_sub_690_912,00m33s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,01m00s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,01m27s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,01m53s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,02m20s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,02m46s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,03m13s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# cnn-07_3117_20180718003124.wav_sub_690_912,03m40s,SCREEN_MATCHUP_EXTRACT_DONE,木雅锅庄,木雅锅庄,巴女母
# ==071==
# cnn-07_3118_20180718011101.wav_sub_948_1128,00m05s,SCREEN_MATCHING
# cnn-07_3118_20180718011101.wav_sub_948_1128,00m25s,SCREEN_NO_MATCH
# cnn-07_3118_20180718011101.wav_sub_948_1128,00m40s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3118_20180718011101.wav_sub_948_1128,01m06s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3118_20180718011101.wav_sub_948_1128,01m32s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3118_20180718011101.wav_sub_948_1128,01m58s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3118_20180718011101.wav_sub_948_1128,02m23s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# cnn-07_3118_20180718011101.wav_sub_948_1128,02m48s,SCREEN_MATCHUP_EXTRACT_DONE,向往,向往,廖昌永
# ==072==
# cnn-07_3121_20180718041101.wav_sub_2073_2253,00m05s,SCREEN_SKIP_FIRST_MATCHUP
# cnn-07_3121_20180718041101.wav_sub_2073_2253,00m34s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# cnn-07_3121_20180718041101.wav_sub_2073_2253,01m02s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# cnn-07_3121_20180718041101.wav_sub_2073_2253,01m29s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# cnn-07_3121_20180718041101.wav_sub_2073_2253,01m56s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# cnn-07_3121_20180718041101.wav_sub_2073_2253,02m23s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# cnn-07_3121_20180718041101.wav_sub_2073_2253,02m49s,SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL,莫斯科郊外的晚上,莫斯科郊外的晚上,
# ==073==
# cnn-07_3124_20180718071101.wav_sub_1206_1368,00m05s,SCREEN_MATCHING
# cnn-07_3124_20180718071101.wav_sub_1206_1368,00m25s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S. 223 - II. Polonaise in E Major",Leslie Howard
# cnn-07_3124_20180718071101.wav_sub_1206_1368,00m54s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S二子…苎二H亡」雇O_OnaiSe in E Major",L=谨‖= 门qu…
# cnn-07_3124_20180718071101.wav_sub_1206_1368,01m23s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S. 223 - II. Polonaise in E Major",Leslie Howard
# cnn-07_3124_20180718071101.wav_sub_1206_1368,01m49s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S. 223 - II. Polonaise in E Major",Leslie Howard
# cnn-07_3124_20180718071101.wav_sub_1206_1368,02m17s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S. 223 - II. Polonaise in E Major",Leslie Howard
# cnn-07_3124_20180718071101.wav_sub_1206_1368,02m46s,SCREEN_MATCHUP_EXTRACT_DONE,"Deux Polonaises, S. 223 - II. Polonaise in E Major","Deux Polonaises, S. 223 - II. Polonaise in E Major",Leslie Howard

# %% [markdown]
# ## Method to get how many tracks are recognized
# * Save the above output to log.txt
# * Filter out '==xxx==' and save it to log.csv
# ```
# rowe8002@SHA-LPC-03759 MINGW64 ~/Documents/eng/n-recognize_track_by_3rdpaty_app/_out_20180806_2330-20180807_0347_log (master)
# $ cat log.txt | grep -v '==0' > log.csv
# ```
#
# * Get the recognized track number
# ```
# rowe8002@SHA-LPC-03759 MINGW64 ~/Documents/eng/n-recognize_track_by_3rdpaty_app/_out_20180806_2330-20180807_0347_log (master)
# $ cat log.csv | grep 'SCREEN_MATCHUP' | cut -d ',' -f 1 | sort |uniq | wc -l
# 56
# ```
