# %% [markdown]
# # SW Preparation
# ### ADB tool
# * [Download the ADB zip file for Windows](https://dl.google.com/android/repository/platform-tools-latest-windows.zip)
# * Extract the contents of this ZIP file into an easily accessible folder (such as C:\android\platform-tools)
# * Connect your android phone / tablet and open command prompt to test if adb is working, detail commands can refer this [article](https://www.howtogeek.com/125769/how-to-install-and-use-abd-the-android-debug-bridge-utility/)
# * Add adb executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### OCR tool
# * [Download tesseract Windows binary](https://github.com/tesseract-ocr/tesseract/wiki/Downloads)
# * Install it as its installer instructed
# * Open command prompt to verify the install
# ```
# (base) C:\Users\rowe8002>tesseract --version
# tesseract 3.05.02
#  leptonica-1.75.3
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 1.5.3) : libpng 1.6.34 : libtiff 4.0.9 : zlib 1.2.11 : libwebp 0.6.1 : libopenjp2 2.2.0
# ```
# * Add tessract executable to Windows PATH [HowTo](https://www.howtogeek.com/118594/how-to-edit-your-system-path-for-easy-command-line-access/)
#
# ### Python package
# * We recommand anacond3 for python package
#     * run **conda search \[packagename\]** to find the package and **conda install \[packagename\]** to install it.
#     * In case the package doesn't in anaconda repository, run **pip search \[packagename\]** to find the package and **pip install \[packagename\]** to install it
# * **PIL / threading / keyboard / os / pyaudio / subprocess / time / wave** are the packages required for this program
#
# ### Third party music recognition APP
# * QQ music (this program was initally written for QQ music)
#
# # HW Preparation
# * android phone (or tablet)
# * usb cable for PC and andriod device connection
#
# Any question please contact wei.rong@nielsen.com

# %%
#!usr/bin/env python  
#coding=utf-8  

from PIL import Image
from threading import Thread
import keyboard
import os
import pyaudio
import subprocess
import time
import wave

# %%
########functions for wav playing########
def _wp_init(f):
    print("_wp_init()...")
    time.sleep(2)
    #instantiate PyAudio  
    p = pyaudio.PyAudio()  
    #open stream  
    stream = p.open(format = p.get_format_from_width(f.getsampwidth()),  
                channels = f.getnchannels(),  
                rate = f.getframerate(),  
                output = True)
    return p, stream

def _wp_run(f,c,s):
    print("_wp_run()...")
    data = f.readframes(c)
    while data:
        if keyboard.is_pressed('q'): break
        s.write(data)
        data = f.readframes(c)

def _wp_deInit(s,p,f):
    print("_wp_deInit()...")
    s.stop_stream()  
    s.close()
    f.close()
    p.terminate()

def wavPlaying(file):
    chunk = 1024
    wavfile = wave.open(file,"rb")  
    p, stream = _wp_init(wavfile)
    _wp_run(wavfile,chunk,stream)
    _wp_deInit(stream,p,wavfile)    

########functions for image crop########
def _im_crop_save(src,des,box):
    img = Image.open(src+".png")
    img2 = img.crop(box)
    img2.save(des+".png")

def _im_add_suffix(src,suffix):
    if os.path.isfile(src+'.png'):
        os.rename(src+'.png',src+'_'+suffix+'.png')
    
def _im_cleanup(name):
    for i in range(3):
        for j in ['png','txt']:
            f = name+'_check0'+str(i+1)+'.'+j
            try:
                os.remove(f)
            except OSError as e:
                #print(e)
                pass

def _im_cleanup_extracted_string(s):
    if s[:4] == '_ 一 ' and s[-4:] == ' 一 _': s = s[4:-4]
    if s[:2] == '一 ' and s[-2:] == ' 一': s = s[2:-2]
    if s[:2] == '— ' and s[-2:] == ' —': s = s[2:-2]
    if s[:1] == '_' and s[-1:] == '_': s = s[1:-1]
    return s.strip()
    
def _im_extract_track_artist(src):
    ret, error, track1, track2, artist = True, [], '', '', ''

    _im_crop_save(src, src+"_matchup_track", (120, 1255, 1080, 1365))
    
    track1 = _ocr_to_string(src+"_matchup_track")
    track1 = _im_cleanup_extracted_string(track1)
    if not len(track1): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL')

    #try with psm7 as single line 
    track2 = _ocr_to_string(src+"_matchup_track",False,'-l chi_sim+eng -psm 7')
    track2 = _im_cleanup_extracted_string(track2)
    if not len(track2): error.append('SCREEN_MATCHUP_EXTRACT_TRACK_PSM7_FAIL')

    _im_crop_save(src, src+"_matchup_artist", (120, 1365, 1080, 1405))
    artist = _ocr_to_string(src+"_matchup_artist",False,'-l chi_sim+eng -psm 7')
    artist = _im_cleanup_extracted_string(artist)
    if not len(artist): error.append('SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL')

    if error == []: error.append('SCREEN_MATCHUP_EXTRACT_DONE')
    return ret, error, track1, track2, artist

########functions for image ocr########
def _ocr_to_string(img, cleanup=False, plus='-l chi_sim+eng'):
    subprocess.check_output('tesseract '+img+'.png'+' '+img+' '+plus, shell=True)
    text = ''
    with open(img + '.txt', 'r', encoding='UTF-8') as f:
        text = f.read().strip().replace('\n',' ')
    if cleanup:
        os.remove(img + '.txt')
    return text

########functions for android manipulation########
def _am_formatDuration(d):
    mins = d//60;
    secs = d - mins*60
    return "%02dm%02ds"%(mins,secs)
    
def _am_getDevices():
    cmd = "adb devices"
    out = subprocess.check_output(cmd.split())
    list = out.decode('utf-8').strip().split('\r\n')
    #print(list)
    return list

def _am_init():
    devices = _am_getDevices()
    if len(devices) <= 1 or '\tdevice' not in devices[-1]:
        cmd = "adb kill-server"
        out = subprocess.check_output(cmd.split())
        time.sleep(5)
        cmd = "adb start-server"
        out = subprocess.check_output(cmd.split())
        list = out.decode('utf-8').strip().split('\r\n')
        print(list)
        if 'successfully' not in list[-1]: return False
    return True

def _am_getScreenSize(st):
    print("%s:_am_getScreenSize " % _am_formatDuration(int(time.time()-st)),end='')
    cmd = "adb shell wm size"
    out = subprocess.check_output(cmd.split())
    size = tuple((out.decode('utf-8').strip().split('\r\n')[0].split(' ')[2].split('x')))
    print(size)
    return size

def _am_launchApp(st):
    time.sleep(2)
    print("%s:_am_launchApp" % _am_formatDuration(int(time.time()-st)))

def _am_CaptureFullScreen(des):
    cmd = "adb shell screencap -p /sdcard/screencap.png"
    out = subprocess.check_output(cmd.split())
    cmd = "adb pull /sdcard/screencap.png %s%s" % (des,".png")
    out = subprocess.check_output(cmd.split())
    if 'pulled' not in out.decode('utf-8').strip():
        print("%s:screencap or pull failed, exit..." % _am_formatDuration(int(time.time()-st)))
        return False, "SCREENCAP_OR_PULL_FAILED"
    return True, "SCREENCAP_AND_PULL_DONE"

def _am_pressBackThenRec():
    cmd = "adb shell input tap 40 90"           #this is back arrow position
    out = subprocess.check_output(cmd.split())
    cmd = "adb shell input tap 300 1715"        #this is recognition icon position
    out = subprocess.check_output(cmd.split())

def _am_pressRetry():
    cmd = "adb shell input tap 600 1530"        #this is re-try buttom
    out = subprocess.check_output(cmd.split())
    cmd = "adb shell input tap 300 1715"        #this is recognition icon position
    out = subprocess.check_output(cmd.split())
    
def _am_onScreenAction(fn,ss,st):
    print("%s:_am_onScreenAction " % _am_formatDuration(int(time.time()-st)), end='')
    
    ret, err = True, 'SCREEN_UNKNOWN'
    
    outdir = "_out"
    os.makedirs(outdir, exist_ok=True)

    #caputre the full sceen
    t = _am_formatDuration(int(time.time()-st))
    name = os.path.join(outdir,"%s_%s" % (fn,t))
    ret, err = _am_CaptureFullScreen(name)
    if not ret: return ret,err

    #crop to have multiple check-point sub-images to identify screen
    _im_crop_save(name, name+"_check01", (0, 180, 1200, 240))   #匹配到以下结果
    _im_crop_save(name, name+"_check02", (0, 610, 1200, 675))   #请求超时/未匹配到结果/无网络连接
    _im_crop_save(name, name+"_check03", (0, 1505, 1200, 1555)) #重试/停止识别/开始识别/重新识别/查看识别历史
    #_im_crop_save(name, name+"_check04", (0, 1750, 1200, 1795)) #听歌识曲 哼唱识别

    if '匹配到以下结果' in _ocr_to_string(name+"_check01"):
        #print(" SCREEN_MATCH_UP")
        ret, err, track1, track2, artist = _im_extract_track_artist(name)
        print(err)
        print(" trackX: %s"%track1)
        print(" trackY: %s"%track2)
        print(" artist: %s"%artist)
        _im_add_suffix(name,'matchup')
        time.sleep(2)
        _am_pressBackThenRec()
    elif '未匹配到结果' in _ocr_to_string(name+"_check02"):
        print("SCREEN_NO_MATCH")
        ret, err =  True, 'SCREEN_NO_MATCH'
        _im_add_suffix(name,'nomatch')
        _am_pressBackThenRec()
    elif '请求超时' in _ocr_to_string(name+"_check02"):
        print("SCREEN_REQ_TIMEOUT")
        ret, err =  True, 'SCREEN_REQ_TIMEOUT'
        _im_add_suffix(name,'timeout')
        _am_pressRetry()
    elif '发生错误了' in _ocr_to_string(name+"_check02"):
        print("SCREEN_ERROR_OCCUR")
        ret, err =  True, 'SCREEN_ERROR_OCCUR'
        _im_add_suffix(name,'errOccur')
        _am_pressRetry()
    elif '停止识别' in _ocr_to_string(name+"_check03"):
        print("SCREEN_MATCHING")
        ret, err =  True, 'SCREEN_MATCHING'
        _im_add_suffix(name,'matching')
    else:
        print("SCREEN_UNKNOWN")
        ret, err = True, 'SCREEN_UNKNOWN'
        _im_add_suffix(name,'unkown')
    
    _im_cleanup(name)
    return ret, err

def androidManipulation(t,fn):
    startTime = time.time()
    if not _am_init():
        print("android manipulation exit due to adb init failure...")
        return

    screenSize = _am_getScreenSize(startTime)
    _am_launchApp(startTime)
#    print(t.ident)
    while t.isAlive():
        ret,errorInfo = _am_onScreenAction(fn,screenSize,startTime)
        if not ret:
            print(errorInfo)
            break
        time.sleep(5)

    print("wav playing ends, exit androidManipulation()")

########wav play & android manipulation threads########
def main(f):
    threadWp = Thread(target=wavPlaying, args=(f,))
    threadWp.start()

    threadAm = Thread(target=androidManipulation, args=(threadWp,os.path.splitext(os.path.basename(f))[0],))
    threadAm.start()

    threadWp.join()
    threadAm.join()

# %%
wavFolder = 'wav_folder'
#wavFolder = 'wav_folder_test'

fileList = os.listdir(wavFolder)
wavList = []
for i in fileList:
    ext = os.path.splitext(os.path.basename(i))[1]
    if '.wav' == ext:
        wavList.append(i)

c = 0
for i in sorted(wavList):
    c = c + 1
    print("\n====================")
    print("[%03d: %s]"%(c,i))
    main(os.path.join(wavFolder,i))
# Out:
# ====================
# [001: cn-t1-01-01_3123_20180718061101.wav_sub_1467_1647.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_UNKNOWN
# 00m22s:_am_onScreenAction SCREEN_MATCHING
# 00m41s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# 01m07s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# 01m33s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# 01m58s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# 02m24s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# 02m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 阳 光下
#  trackY: 阳 光下
#  artist: 满江
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [002: cn-t1-03-01_3097_20180717071101.wav_sub_1817_1997.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m37s:_am_onScreenAction SCREEN_MATCHING
# 00m54s:_am_onScreenAction SCREEN_MATCHING
# 01m12s:_am_onScreenAction SCREEN_NO_MATCH
# 01m27s:_am_onScreenAction SCREEN_MATCHING
# 01m46s:_am_onScreenAction SCREEN_NO_MATCH
# 02m00s:_am_onScreenAction SCREEN_MATCHING
# 02m19s:_am_onScreenAction SCREEN_NO_MATCH
# 02m33s:_am_onScreenAction SCREEN_MATCHING
# 02m51s:_am_onScreenAction SCREEN_NO_MATCH
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [003: cn-t1-03-01_3097_20180717071101.wav_sub_738_917.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction SCREEN_MATCHING
# 00m53s:_am_onScreenAction SCREEN_NO_MATCH
# 01m08s:_am_onScreenAction SCREEN_MATCHING
# 01m26s:_am_onScreenAction SCREEN_NO_MATCH
# 01m40s:_am_onScreenAction SCREEN_MATCHING
# 01m58s:_am_onScreenAction SCREEN_NO_MATCH
# 02m12s:_am_onScreenAction SCREEN_MATCHING
# 02m30s:_am_onScreenAction SCREEN_NO_MATCH
# 02m45s:_am_onScreenAction SCREEN_MATCHING
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [004: cn-t1-03-01_3124_20180718071101.wav_sub_1967_2027.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m35s:_am_onScreenAction SCREEN_NO_MATCH
# 00m50s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [005: cn-t1-03-01_3125_20180718081101.wav_sub_476_656.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m35s:_am_onScreenAction SCREEN_NO_MATCH
# 00m51s:_am_onScreenAction SCREEN_MATCHING
# 01m09s:_am_onScreenAction SCREEN_NO_MATCH
# 01m24s:_am_onScreenAction SCREEN_MATCHING
# 01m42s:_am_onScreenAction SCREEN_NO_MATCH
# 01m57s:_am_onScreenAction SCREEN_MATCHING
# 02m16s:_am_onScreenAction SCREEN_NO_MATCH
# 02m30s:_am_onScreenAction SCREEN_MATCHING
# 02m48s:_am_onScreenAction SCREEN_NO_MATCH
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [006: cn-t1-04-01_3096_20180717061100.wav_sub_2456_2558.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction SCREEN_MATCHING
# 00m56s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 视讯 电话
#  trackY: 视讯 电话
#  artist: 程恢弘
# 01m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 视讯 电话
#  trackY: 视讯 电话
#  artist: 程恢弘
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [007: cn-t1-04-01_3123_20180718061101.wav_sub_2093_2117.wav]
# _wp_init()...
# 00m01s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 视讯 电话
#  trackY: 视讯 电话
#  artist: 程恢弘
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [008: cn-t1-05-01_3080_20180716141101.wav_sub_3356_3362.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 视讯 电话
#  trackY: 视讯 电话
#  artist: 程恢弘
# wav playing ends, exit androidManipulation()
#
# ====================
# [009: cn-t1-05-01_3087_20180716211101.wav_sub_2489_2663.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# 01m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# 01m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# 01m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# 02m18s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# 02m43s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 胃春终老
#  trackY: 胃春终老
#  artist: 一 Robynn & Kendy —
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [010: cn-t1-05-01_3088_20180716221101.wav_sub_515_689.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# 00m44s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# 01m09s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# 01m32s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# 01m56s:_am_onScreenAction SCREEN_MATCHING
# 02m14s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# 02m37s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 口乎 _]及
#  trackY: 口乎 _]及
#  artist: 丢火车乐队
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [011: cn-t1-05-01_3089_20180716231101.wav_sub_866_1040.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 00m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 01m12s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 01m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 02m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 02m26s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# 02m50s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不思议少年
#  trackY: 不思议少年
#  artist: 易安音乐社
# wav playing ends, exit androidManipulation()
#
# ====================
# [012: cn-t1-05-01_3091_20180717011103.wav_sub_344_512.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m20s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# 01m00s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# 01m25s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# 01m50s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# 02m15s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# 02m40s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 想用你名 字命名 的歌
#  trackY: 想用你名 字命名 的歌
#  artist: 木丽妍
# wav playing ends, exit androidManipulation()
#
# ====================
# [013: cn-t1-05-01_3091_20180717011103.wav_sub_827_953.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m20s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 从此跟着你流浪去很远的地方
#  trackY: 从此跟着你流浪去很远的地方
#  artist: — ReDor锐豆乐队 一
# 01m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 从此跟着你流浪去很远的地方
#  trackY: 从此跟着你流浪去很远的地方
#  artist: — ReDor锐豆乐队 一
# 01m27s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 从此跟着你流浪去很远的地方
#  trackY: 从此跟着你流浪去很远的地方
#  artist: — ReDor锐豆乐队 一
# 01m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 从此跟着你流浪去很远的地方
#  trackY: 从此跟着你流浪去很远的地方
#  artist: — ReDor锐豆乐队 一
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [014: cn-t1-05-01_3101_20180717111101.wav_sub_2364_2543.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有心
#  trackY: 有心
#  artist: 范振锋/张玉珊
# 00m47s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有心
#  trackY: 有心
#  artist: 范振锋/张玉珊
# 01m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有心
#  trackY: 有心
#  artist: 范振锋/张玉珊
# 01m39s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有心
#  trackY: 有心
#  artist: 范振锋/张玉珊
# 02m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有/〔′\  一 了蒿旧今又闸烂工I皿 一
#  trackY: 一 :mELEAImn _
#  artist: 飓鲨萱冥上乏唰
# 02m31s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 有心
#  trackY: 有心
#  artist: 范振锋/张玉珊
# 02m59s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 。 [ 们广一胪烨闺 〇 ...
#  artist: 一
# wav playing ends, exit androidManipulation()
#
# ====================
# [015: cn-t1-05-01_3112_20180717211101.wav_sub_2489_2669.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 00m50s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 01m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 01m42s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 02m08s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 02m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [016: cn-t1-05-01_3118_20180718011101.wav_sub_1607_1655.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 沉默的士高
#  trackY: 沉默的士高
#  artist: 王菀之
# 00m30s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Just Call It Love
#  trackY: We Just Call It Love
#  artist: 肆嚣乐队
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [017: cn-t1-05-01_3119_20180718021101.wav_sub_1907_2087.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction SCREEN_MATCHING
# 00m58s:_am_onScreenAction SCREEN_NO_MATCH
# 01m13s:_am_onScreenAction SCREEN_MATCHING
# 01m32s:_am_onScreenAction SCREEN_NO_MATCH
# 01m47s:_am_onScreenAction SCREEN_MATCHING
# 02m07s:_am_onScreenAction SCREEN_NO_MATCH
# 02m22s:_am_onScreenAction SCREEN_MATCHING
# 02m41s:_am_onScreenAction SCREEN_NO_MATCH
# 02m56s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [018: cn-t1-05-01_3121_20180718041101.wav_sub_3311_3365.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 偶遇
#  trackY: 偶遇
#  artist: 王菲
# 00m45s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 偶遇
#  trackY: 偶遇
#  artist: 王菲
# wav playing ends, exit androidManipulation()
#
# ====================
# [019: cn-t1-05-01_3123_20180718061101.wav_sub_1406_1988.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 00m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 01m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 01m44s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 02m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 02m41s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′'′霞  飞飞
#  trackY: 麟   富亳… 薯誓青二'
#  artist: 杨家成
# 03m07s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 03m34s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 04m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 04m32s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 05m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 05m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 甜姐辣妹
#  trackY: 甜姐辣妹
#  artist: 许玮宁/姚安琪
# 05m56s:_am_onScreenAction SCREEN_MATCHING
# 06m15s:_am_onScreenAction SCREEN_NO_MATCH
# 06m32s:_am_onScreenAction SCREEN_MATCHING
# 06m51s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# 07m17s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# 07m44s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# 08m10s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# 08m39s:_am_onScreenAction SCREEN_MATCHING
# 08m59s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# 09m27s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱你呦
#  trackY: 爱你呦
#  artist: 小雅/杨家成
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [020: cn-t1-05-01_3123_20180718061101.wav_sub_2327_2735.wav]
# _wp_init()...
# 00m01s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m05s:_am_launchApp
# 00m05s:_am_onScreenAction SCREEN_UNKNOWN
# 00m26s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 00m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 01m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 01m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 02m12s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 02m39s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 03m05s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 你的好
#  trackY: 你的好
#  artist: 林采欣
# 03m33s:_am_onScreenAction SCREEN_MATCHING
# 03m52s:_am_onScreenAction SCREEN_NO_MATCH
# 04m06s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 04m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 05m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 05m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 05m55s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 06m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# 06m47s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 快乐星球
#  trackY: 快乐星球
#  artist: /J、雅
# wav playing ends, exit androidManipulation()
#
# ====================
# [021: cn-t1-05-01_3125_20180718081101.wav_sub_678_857.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 心仍  曰\〈 天E/7
#  trackY: 心仍罡冷
#  artist: 杨千婵
# 01m03s:_am_onScreenAction SCREEN_MATCHING
# 01m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 心仍  曰\〈 天E/7
#  trackY: 心仍罡冷
#  artist: 杨千婵
# 01m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 心仍  曰\〈 天E/7
#  trackY: 心仍罡冷
#  artist: 杨千婵
# 02m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 心仍  曰\〈 天E/7
#  trackY: 心仍罡冷
#  artist: 杨千婵
# 02m42s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 心仍  曰\〈 天E/7
#  trackY: 心仍罡冷
#  artist: 杨千婵
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [022: cn-t1-06-01_3080_20180716141101.wav_sub_1497_1677.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m37s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# 01m03s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# 01m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# 01m55s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# 02m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# 02m48s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 配角
#  trackY: 配角
#  artist: 顾海滨
# wav playing ends, exit androidManipulation()
#
# ====================
# [023: cn-t1-06-01_3085_20180716191101.wav_sub_3192_3360.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m37s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法 (伴奏)
#  trackY: 闪壳的魔法 (伴奏)
#  artist: 周笔畅
# 01m05s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 01m33s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 02m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 02m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [024: cn-t1-06-01_3089_20180716231101.wav_sub_3228_3408.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 01m07s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 01m34s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 02m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 02m27s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# 02m55s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 闪壳的魔法
#  trackY: 闪壳的魔法
#  artist: 周笔畅
# wav playing ends, exit androidManipulation()
#
# ====================
# [025: cn-t1-06-01_3098_20180717081101.wav_sub_945_1125.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# 00m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# 01m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# 01m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# 02m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# 02m41s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 需要你的爱
#  trackY: 需要你的爱
#  artist: 飞儿乐团/信
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [026: cn-t1-07-01_3086_20180716201101.wav_sub_2693_2855.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# 00m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# 01m14s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# 01m42s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# 02m08s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# 02m34s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 知道不知道
#  trackY: 知道不知道
#  artist: 胡夏
# wav playing ends, exit androidManipulation()
#
# ====================
# [027: cn-t1-07-01_3090_20180717001101.wav_sub_2234_2396.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 告别
#  artist: 黄大炜
# 01m03s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 告别
#  artist: 黄大炜
# 01m29s:_am_onScreenAction SCREEN_MATCHING
# 01m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 告别
#  artist: 黄大炜
# 02m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 告别
#  artist: 黄大炜
# 02m42s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [028: cn-t1-07-01_3091_20180717011103.wav_sub_2573_2603.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 告别
#  artist: 黄大炜
# 00m30s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 贵钞 \卜_ 方 言
#  trackY: 贵州 方言
#  artist: 王羽
# wav playing ends, exit androidManipulation()
#
# ====================
# [029: cn-t1-07-01_3092_20180717021101.wav_sub_1817_2747.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m24s:_am_onScreenAction SCREEN_NO_MATCH
# 00m39s:_am_onScreenAction SCREEN_MATCHING
# 00m58s:_am_onScreenAction SCREEN_NO_MATCH
# 01m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 开往锡城的火车
#  trackY: 开往锡城的火车
#  artist: 徐艺伦
# 01m40s:_am_onScreenAction SCREEN_MATCHING
# 01m59s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 开往锡城的火车
#  trackY: 开往锡城的火车
#  artist: 徐艺伦
# 02m27s:_am_onScreenAction SCREEN_MATCHING
# 02m47s:_am_onScreenAction SCREEN_NO_MATCH
# 03m03s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 开往锡城的火车
#  trackY: 开往锡城的火车
#  artist: 徐艺伦
# 03m31s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 开往锡城的火车
#  trackY: 开往锡城的火车
#  artist: 徐艺伦
# 04m00s:_am_onScreenAction SCREEN_MATCHING
# 04m19s:_am_onScreenAction SCREEN_NO_MATCH
# 04m34s:_am_onScreenAction SCREEN_MATCHING
# 04m54s:_am_onScreenAction SCREEN_NO_MATCH
# 05m10s:_am_onScreenAction SCREEN_MATCHING
# 05m30s:_am_onScreenAction SCREEN_NO_MATCH
# 05m44s:_am_onScreenAction SCREEN_MATCHING
# 06m04s:_am_onScreenAction SCREEN_NO_MATCH
# 06m20s:_am_onScreenAction SCREEN_MATCHING
# 06m39s:_am_onScreenAction SCREEN_NO_MATCH
# 06m54s:_am_onScreenAction SCREEN_MATCHING
# 07m15s:_am_onScreenAction SCREEN_NO_MATCH
# 07m31s:_am_onScreenAction SCREEN_MATCHING
# 07m50s:_am_onScreenAction SCREEN_NO_MATCH
# 08m06s:_am_onScreenAction SCREEN_MATCHING
# 08m27s:_am_onScreenAction SCREEN_NO_MATCH
# 08m41s:_am_onScreenAction SCREEN_MATCHING
# 09m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 09m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 09m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 10m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 10m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 11m12s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 11m38s:_am_onScreenAction SCREEN_MATCHING
# 11m57s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木头人
#  trackY: 木头人
#  artist: 徐艺伦
# 12m25s:_am_onScreenAction SCREEN_MATCHING
# 12m44s:_am_onScreenAction SCREEN_NO_MATCH
# 12m59s:_am_onScreenAction SCREEN_MATCHING
# 13m21s:_am_onScreenAction SCREEN_NO_MATCH
# 13m36s:_am_onScreenAction SCREEN_MATCHING
# 13m56s:_am_onScreenAction SCREEN_NO_MATCH
# 14m11s:_am_onScreenAction SCREEN_MATCHING
# 14m32s:_am_onScreenAction SCREEN_NO_MATCH
# 14m47s:_am_onScreenAction SCREEN_MATCHING
# 15m07s:_am_onScreenAction SCREEN_NO_MATCH
# 15m23s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [030: cn-t1-07-01_3106_20180717154141.wav_sub_35_197.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# 00m50s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# 01m18s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# 01m48s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# 02m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [031: cn-t1-07-01_3118_20180718011101.wav_sub_893_1061.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: _场雨落下来要用 多久
#  trackY: _场雨落下来要用 多久
#  artist: 鹿先森乐队
# 00m31s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Tango Azul
#  trackY: Tango Azul
#  artist: Guitarra AZu_
# 01m01s:_am_onScreenAction SCREEN_MATCHING
# 01m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Tango Azul
#  trackY: Tango Azul
#  artist: Guitarra AZu_
# 01m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Tango Azul
#  trackY: Tango Azul
#  artist: Guitarra AZu_
# 02m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Tango Azul
#  trackY: Tango Azul
#  artist: Guitarra AZu_
# 02m42s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Tango Azul
#  trackY: Tango Azul
#  artist: Guitarra AZu_
# wav playing ends, exit androidManipulation()
#
# ====================
# [032: cn-t1-07-01_3125_20180718081101.wav_sub_1812_1991.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m24s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# 00m54s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# 01m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# 01m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# 02m15s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# 02m46s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 背后女人
#  trackY: 背后女人
#  artist: 杨千婵/周柏熹
# wav playing ends, exit androidManipulation()
#
# ====================
# [033: cn-t1-08-01_3084_20180716181101.wav_sub_1034_1214.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction SCREEN_MATCHING
# 00m59s:_am_onScreenAction SCREEN_NO_MATCH
# 01m14s:_am_onScreenAction SCREEN_MATCHING
# 01m34s:_am_onScreenAction SCREEN_NO_MATCH
# 01m48s:_am_onScreenAction SCREEN_MATCHING
# 02m08s:_am_onScreenAction SCREEN_NO_MATCH
# 02m23s:_am_onScreenAction SCREEN_MATCHING
# 02m43s:_am_onScreenAction SCREEN_NO_MATCH
# 02m58s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [034: cn-t1-08-01_3084_20180716181101.wav_sub_3173_3179.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction _wp_deInit()...
# SCREEN_NO_MATCH
# wav playing ends, exit androidManipulation()
#
# ====================
# [035: cn-t1-08-01_3100_20180717101101.wav_sub_2079_2258.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 那英/ 张惠妹/林忆莲/蔡健雅
# 00m51s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 那英/ 张惠妹/林忆莲/蔡健雅
# 01m19s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 那英/ 张惠妹/林忆莲/蔡健雅
# 01m47s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 那英/ 张惠妹/林忆莲/蔡健雅
# 02m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 那英/ 张惠妹/林忆莲/蔡健雅
# 02m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: We Are One
#  trackY: We Are One
#  artist: 华语群星
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [036: cn-t1-08-01_3101_20180717111101.wav_sub_1260_1439.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m25s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# 00m52s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# 01m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# 01m48s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# 02m15s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# 02m46s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: When _ Was Your Man
#  trackY: When _ Was Your Man
#  artist: 一 Sam Smith —
# wav playing ends, exit androidManipulation()
#
# ====================
# [037: cn-t1-08-01_3106_20180717154140.wav_sub_1187_1343.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m26s:_am_onScreenAction SCREEN_NO_MATCH
# 00m41s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 给力胃春
#  trackY: 给力胃春
#  artist: 群星
# 01m09s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 给力胃春
#  trackY: 给力胃春
#  artist: 群星
# 01m39s:_am_onScreenAction SCREEN_MATCHING
# 02m03s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 给力胃春
#  trackY: 给力胃春
#  artist: 群星
# 02m34s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 给力胃春
#  trackY: 给力胃春
#  artist: 群星
# wav playing ends, exit androidManipulation()
#
# ====================
# [038: cn-t1-08-01_3106_20180717154140.wav_sub_1638_1817.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# 01m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# 01m27s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# 01m52s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# 02m17s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# 02m41s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: | Lomo You (Demo)
#  trackY: | Lomo You (Demo)
#  artist: GALA
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [039: cn-t1-08-01_3125_20180718081101.wav_sub_3146_3170.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Cool
#  trackY: Cool
#  artist: 丁Winnie
# wav playing ends, exit androidManipulation()
#
# ====================
# [040: cnn-01_3084_20180716181100.wav_sub_1874_2054.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 01m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 01m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 01m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 02m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 02m45s:_am_onScreenAction SCREEN_MATCHING
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [041: cnn-01_3084_20180716181100.wav_sub_522_701.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 哪里哪里
#  trackY: 哪里哪里
#  artist: 叶柔
# 00m29s:_am_onScreenAction SCREEN_MATCHING
# 00m47s:_am_onScreenAction SCREEN_NO_MATCH
# 01m01s:_am_onScreenAction SCREEN_MATCHING
# 01m20s:_am_onScreenAction SCREEN_NO_MATCH
# 01m34s:_am_onScreenAction SCREEN_MATCHING
# 01m53s:_am_onScreenAction SCREEN_NO_MATCH
# 02m07s:_am_onScreenAction SCREEN_MATCHING
# 02m25s:_am_onScreenAction SCREEN_NO_MATCH
# 02m39s:_am_onScreenAction SCREEN_MATCHING
# 02m57s:_am_onScreenAction _wp_deInit()...
# SCREEN_NO_MATCH
# wav playing ends, exit androidManipulation()
#
# ====================
# [042: cnn-01_3085_20180716191101.wav_sub_596_740.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 00m45s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 01m10s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 01m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 02m00s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 02m24s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [043: cnn-01_3093_20180717031101.wav_sub_444_623.wav]
# _wp_init()...
# 00m01s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 敲内脑
#  trackY: 敲内脑
#  artist: 陈萝莉
# 00m32s:_am_onScreenAction SCREEN_MATCHING
# 00m50s:_am_onScreenAction SCREEN_NO_MATCH
# 01m06s:_am_onScreenAction SCREEN_MATCHING
# 01m26s:_am_onScreenAction SCREEN_NO_MATCH
# 01m40s:_am_onScreenAction SCREEN_MATCHING
# 01m59s:_am_onScreenAction SCREEN_NO_MATCH
# 02m16s:_am_onScreenAction SCREEN_MATCHING
# 02m38s:_am_onScreenAction SCREEN_NO_MATCH
# 02m54s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [044: cnn-01_3096_20180717061100.wav_sub_1460_1598.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不准你走
#  trackY: 不准你走
#  artist: 钟镇涛
# 00m44s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不准你走
#  trackY: 不准你走
#  artist: 钟镇涛
# 01m10s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不准你走
#  trackY: 不准你走
#  artist: 钟镇涛
# 01m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不准你走
#  trackY: 不准你走
#  artist: 钟镇涛
# 02m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 不准你走
#  trackY: 不准你走
#  artist: 钟镇涛
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [045: cnn-01_3098_20180717081100.wav_sub_2613_2792.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m36s:_am_onScreenAction SCREEN_MATCHING
# 00m53s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 共圆中国梦
#  trackY: 共圆中国梦
#  artist: 刘晶/阎维文
# 01m20s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 共圆中国梦
#  trackY: 共圆中国梦
#  artist: 刘晶/阎维文
# 01m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 共圆中国梦
#  trackY: 共圆中国梦
#  artist: 刘晶/阎维文
# 02m11s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 共圆中国梦
#  trackY: 共圆中国梦
#  artist: 刘晶/阎维文
# 02m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 共圆中国梦
#  trackY: 共圆中国梦
#  artist: 刘晶/阎维文
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [046: cnn-01_3106_20180717154139.wav_sub_2346_2525.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction SCREEN_MATCHING
# 00m53s:_am_onScreenAction SCREEN_NO_MATCH
# 01m07s:_am_onScreenAction SCREEN_MATCHING
# 01m27s:_am_onScreenAction SCREEN_NO_MATCH
# 01m41s:_am_onScreenAction SCREEN_MATCHING
# 01m59s:_am_onScreenAction SCREEN_NO_MATCH
# 02m13s:_am_onScreenAction SCREEN_MATCHING
# 02m33s:_am_onScreenAction SCREEN_NO_MATCH
# 02m47s:_am_onScreenAction SCREEN_MATCHING
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [047: cnn-01_3120_20180718031101.wav_sub_2237_2375.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m19s:_am_onScreenAction SCREEN_MATCHING
# 00m37s:_am_onScreenAction SCREEN_NO_MATCH
# 00m51s:_am_onScreenAction SCREEN_MATCHING
# 01m09s:_am_onScreenAction SCREEN_NO_MATCH
# 01m23s:_am_onScreenAction SCREEN_MATCHING
# 01m41s:_am_onScreenAction SCREEN_NO_MATCH
# 01m55s:_am_onScreenAction SCREEN_MATCHING
# 02m13s:_am_onScreenAction _wp_deInit()...
# SCREEN_NO_MATCH
# wav playing ends, exit androidManipulation()
#
# ====================
# [048: cnn-01_3125_20180718081101.wav_sub_2652_2831.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m34s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱国歌
#  trackY: 爱国歌
#  artist: 喻越越/蔡鹏
# 01m01s:_am_onScreenAction SCREEN_MATCHING
# 01m19s:_am_onScreenAction SCREEN_NO_MATCH
# 01m33s:_am_onScreenAction SCREEN_MATCHING
# 01m51s:_am_onScreenAction SCREEN_NO_MATCH
# 02m06s:_am_onScreenAction SCREEN_MATCHING
# 02m24s:_am_onScreenAction SCREEN_NO_MATCH
# 02m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 爱国歌
#  trackY: 爱国歌
#  artist: 喻越越/蔡鹏
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [049: cnn-01_3125_20180718081101.wav_sub_591_770.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m36s:_am_onScreenAction SCREEN_MATCHING
# 00m54s:_am_onScreenAction SCREEN_NO_MATCH
# 01m08s:_am_onScreenAction SCREEN_MATCHING
# 01m26s:_am_onScreenAction SCREEN_NO_MATCH
# 01m40s:_am_onScreenAction SCREEN_MATCHING
# 02m01s:_am_onScreenAction SCREEN_NO_MATCH
# 02m16s:_am_onScreenAction SCREEN_MATCHING
# 02m34s:_am_onScreenAction SCREEN_NO_MATCH
# 02m49s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [050: cnn-02_3097_20180717071101.wav_sub_1236_1415.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m36s:_am_onScreenAction SCREEN_NO_MATCH
# 00m51s:_am_onScreenAction SCREEN_MATCHING
# 01m09s:_am_onScreenAction SCREEN_NO_MATCH
# 01m23s:_am_onScreenAction SCREEN_MATCHING
# 01m41s:_am_onScreenAction SCREEN_NO_MATCH
# 01m55s:_am_onScreenAction SCREEN_MATCHING
# 02m13s:_am_onScreenAction SCREEN_NO_MATCH
# 02m27s:_am_onScreenAction SCREEN_MATCHING
# 02m45s:_am_onScreenAction SCREEN_NO_MATCH
# 03m00s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [051: cnn-02_3098_20180717081101.wav_sub_1158_1535.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m03s:_am_launchApp
# 00m03s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 依呀呀
#  trackY: 依呀呀
#  artist: 孙羡真
# 01m01s:_am_onScreenAction SCREEN_MATCHING
# 01m20s:_am_onScreenAction SCREEN_NO_MATCH
# 01m35s:_am_onScreenAction SCREEN_MATCHING
# 01m52s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 依呀呀
#  trackY: 依呀呀
#  artist: 孙羡真
# 02m18s:_am_onScreenAction SCREEN_MATCHING
# 02m36s:_am_onScreenAction SCREEN_NO_MATCH
# 02m50s:_am_onScreenAction SCREEN_MATCHING
# 03m08s:_am_onScreenAction SCREEN_NO_MATCH
# 03m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 03m47s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 04m11s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 04m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 04m59s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 05m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 05m48s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# 06m12s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Heart Speak (Dzeko vs. Waves Remix)
#  trackY: Heart Speak (Dzeko vs. Waves Remix)
#  artist: 一 Dzeko/TO KA-J —
# wav playing ends, exit androidManipulation()
#
# ====================
# [052: cnn-02_3098_20180717081101.wav_sub_2258_2438.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m39s:_am_onScreenAction SCREEN_MATCHING
# 01m00s:_am_onScreenAction SCREEN_NO_MATCH
# 01m14s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Bach, JS 二 Erbarm' dich mein, O Herre Gott BWV72‘I
#  trackY: Bach, JS 二 E「ba「「琶'V聂暧妻2审em′ O Herre Gott
#  artist: Marie-Claire Alain
# 01m40s:_am_onScreenAction SCREEN_MATCHING
# 02m00s:_am_onScreenAction SCREEN_NO_MATCH
# 02m14s:_am_onScreenAction SCREEN_MATCHING
# 02m34s:_am_onScreenAction SCREEN_NO_MATCH
# 02m50s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [053: cnn-02_3124_20180718071101.wav_sub_1463_1781.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Metallica 一 Enter Sandman
#  trackY: Metallica 一 Enter Sandman
#  artist: Metallica
# 01m03s:_am_onScreenAction SCREEN_MATCHING
# 01m20s:_am_onScreenAction SCREEN_NO_MATCH
# 01m35s:_am_onScreenAction SCREEN_MATCHING
# 01m53s:_am_onScreenAction SCREEN_NO_MATCH
# 02m07s:_am_onScreenAction SCREEN_MATCHING
# 02m25s:_am_onScreenAction SCREEN_NO_MATCH
# 02m40s:_am_onScreenAction SCREEN_MATCHING
# 02m58s:_am_onScreenAction SCREEN_NO_MATCH
# 03m13s:_am_onScreenAction SCREEN_MATCHING
# 03m34s:_am_onScreenAction SCREEN_NO_MATCH
# 03m48s:_am_onScreenAction SCREEN_MATCHING
# 04m06s:_am_onScreenAction SCREEN_NO_MATCH
# 04m20s:_am_onScreenAction SCREEN_MATCHING
# 04m39s:_am_onScreenAction SCREEN_NO_MATCH
# 04m53s:_am_onScreenAction SCREEN_MATCHING
# 05m11s:_am_onScreenAction SCREEN_NO_MATCH
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [054: cnn-02_3124_20180718071101.wav_sub_2381_2399.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [055: cnn-02_3124_20180718071101.wav_sub_962_1250.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m36s:_am_onScreenAction SCREEN_NO_MATCH
# 00m50s:_am_onScreenAction SCREEN_MATCHING
# 01m09s:_am_onScreenAction SCREEN_NO_MATCH
# 01m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Hello (Centra Remix)
#  trackY: Hello (Centra Remix)
#  artist: Going Quantum
# 01m48s:_am_onScreenAction SCREEN_MATCHING
# 02m06s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: All Good Things
#  trackY: All Good Things
#  artist: Lost Stories
# 02m30s:_am_onScreenAction SCREEN_MATCHING
# 02m49s:_am_onScreenAction SCREEN_NO_MATCH
# 03m03s:_am_onScreenAction SCREEN_MATCHING
# 03m22s:_am_onScreenAction SCREEN_NO_MATCH
# 03m36s:_am_onScreenAction SCREEN_MATCHING
# ...
#  trackX:
#  trackY: 康定情歌与溜溜调 (Live)
#  artist: 谭维维
# 03m56s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 康定情歌与溜溜调 (Live)
#  artist: 谭维维
# 04m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL']
#  trackX:
#  trackY: 康定情歌与溜溜调 (Live)
#  artist: 谭维维
# 04m49s:_am_onScreenAction SCREEN_MATCHING
# 05m07s:_am_onScreenAction SCREEN_NO_MATCH
# 05m22s:_am_onScreenAction SCREEN_MATCHING
# 05m40s:_am_onScreenAction SCREEN_NO_MATCH
# 05m54s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 在水_方
#  trackY: 在水_方
#  artist: 传奇乐坊
# 06m19s:_am_onScreenAction SCREEN_MATCHING
# 06m37s:_am_onScreenAction SCREEN_NO_MATCH
# 06m52s:_am_onScreenAction SCREEN_MATCHING
# 07m10s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 07m36s:_am_onScreenAction SCREEN_MATCHING
# 07m54s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 08m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 08m48s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 09m14s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 09m39s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 10m05s:_am_onScreenAction SCREEN_MATCHING
# 10m25s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 10m50s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# 11m17s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: ′_`…肖… 3*" /两康 定
#  trackY: 情满康定
#  artist: 李志辉
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [061: cnn-07_3094_20180717041101.wav_sub_1494_1674.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m36s:_am_onScreenAction SCREEN_MATCHING
# 00m54s:_am_onScreenAction SCREEN_NO_MATCH
# 01m08s:_am_onScreenAction SCREEN_MATCHING
# 01m27s:_am_onScreenAction SCREEN_NO_MATCH
# 01m41s:_am_onScreenAction SCREEN_MATCHING
# 01m59s:_am_onScreenAction SCREEN_NO_MATCH
# 02m14s:_am_onScreenAction SCREEN_MATCHING
# 02m34s:_am_onScreenAction SCREEN_NO_MATCH
# 02m48s:_am_onScreenAction SCREEN_MATCHING
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [062: cnn-07_3095_20180717051101.wav_sub_2655_2835.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m18s:_am_onScreenAction SCREEN_MATCHING
# 00m37s:_am_onScreenAction SCREEN_NO_MATCH
# 00m52s:_am_onScreenAction SCREEN_MATCHING
# 01m10s:_am_onScreenAction SCREEN_NO_MATCH
# 01m25s:_am_onScreenAction SCREEN_MATCHING
# 01m45s:_am_onScreenAction SCREEN_REQ_TIMEOUT
# 02m02s:_am_onScreenAction SCREEN_MATCHING
# 02m21s:_am_onScreenAction SCREEN_NO_MATCH
# 02m36s:_am_onScreenAction SCREEN_MATCHING
# 02m54s:_am_onScreenAction SCREEN_NO_MATCH
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [063: cnn-07_3096_20180717061101.wav_sub_2148_2328.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# 00m47s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# 01m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# 01m38s:_am_onScreenAction SCREEN_MATCHING
# 01m56s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# 02m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# 02m48s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Monica (Live)
#  trackY: Monica (Live)
#  artist: 古巨墓
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [064: cnn-07_3098_20180717081101.wav_sub_1386_1566.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)
#  trackY: Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 "
#  artist: Classical Artists
# 00m51s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)
#  trackY: Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 "
#  artist: Classical Artists
# 01m21s:_am_onScreenAction SCREEN_MATCHING
# 01m39s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Don Giovanni, K.527 / ACt1 - Madamina, il catalogo é questo (亲爱的天人呀， 这就是名 单)
#  trackY: ca邑?藿g冒i亘V写…写具壬薯鬓鬟'白含昊又喋a霆蛊逞a名i隼)
#  artist: 一 Teddy Tahu Rhodes/Tasmanian Symphony Orchestra/Ola Rudner —
# 02m13s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)
#  trackY: Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 "
#  artist: Classical Artists
# 02m43s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Don Giovanni′ K. 527, Act 1: Madamina! I| catalogo e questo (Catalogue Aria)
#  trackY: Do「墓星写邕菖霍n翼 累羁 镶碳觐霏 "
#  artist: Classical Artists
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [065: cnn-07_3098_20180717081101.wav_sub_2373_2739.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m21s:_am_onScreenAction SCREEN_NO_MATCH
# 00m35s:_am_onScreenAction SCREEN_MATCHING
# 00m57s:_am_onScreenAction SCREEN_NO_MATCH
# 01m11s:_am_onScreenAction SCREEN_MATCHING
# 01m30s:_am_onScreenAction SCREEN_NO_MATCH
# 01m46s:_am_onScreenAction SCREEN_MATCHING
# 02m09s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Piano Concerto No. 21 in C major, K. 467 — Andante
#  trackY: Piano Concerto hrﬁd2a1nigc major, K. 467 —
#  artist: Yu Kosuge (/J、菅 1蔓)
# 02m35s:_am_onScreenAction SCREEN_MATCHING
# 02m55s:_am_onScreenAction SCREEN_NO_MATCH
# 03m11s:_am_onScreenAction SCREEN_MATCHING
# 03m30s:_am_onScreenAction SCREEN_NO_MATCH
# 03m46s:_am_onScreenAction SCREEN_MATCHING
# 04m05s:_am_onScreenAction SCREEN_NO_MATCH
# 04m19s:_am_onScreenAction SCREEN_MATCHING
# 04m37s:_am_onScreenAction SCREEN_NO_MATCH
# 04m52s:_am_onScreenAction SCREEN_MATCHING
# 05m10s:_am_onScreenAction SCREEN_NO_MATCH
# 05m24s:_am_onScreenAction SCREEN_MATCHING
# 05m43s:_am_onScreenAction SCREEN_NO_MATCH
# 06m00s:_am_onScreenAction _wp_deInit()...
# SCREEN_MATCHING
# wav playing ends, exit androidManipulation()
#
# ====================
# [066: cnn-07_3110_20180717191101.wav_sub_2040_2220.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_NO_MATCH
# 00m19s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 蒙古人
#  trackY: 蒙古人
#  artist: Various Artists
# 00m45s:_am_onScreenAction SCREEN_MATCHING
# 01m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 蒙古人
#  trackY: 蒙古人
#  artist: Various Artists
# 01m31s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 蒙古人
#  trackY: 蒙古人
#  artist: Various Artists
# 01m56s:_am_onScreenAction SCREEN_MATCHING
# 02m17s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 蒙古人
#  trackY: 蒙古人
#  artist: Various Artists
# 02m43s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 蒙古人
#  trackY: 蒙古人
#  artist: Various Artists
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [067: cnn-07_3110_20180717191101.wav_sub_2649_2805.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 新编阿里郎
#  trackY: 新编阿里郎
#  artist: 金皇
# 01m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 新编阿里郎
#  trackY: 新编阿里郎
#  artist: 金皇
# 01m30s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 新编阿里郎
#  trackY: 新编阿里郎
#  artist: 金皇
# 01m58s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 新编阿里郎
#  trackY: 新编阿里郎
#  artist: 金皇
# 02m25s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 新编阿里郎
#  trackY: 新编阿里郎
#  artist: 金皇
# wav playing ends, exit androidManipulation()
#
# ====================
# [068: cnn-07_3110_20180717191101.wav_sub_969_1617.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction SCREEN_NO_MATCH
# 00m37s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 01m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 01m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 01m55s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 02m21s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 02m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 03m11s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 03m37s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 04m02s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 04m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 重逢
#  trackY: 重逢
#  artist: 常石磊/马上又/袁娅维/李佳
# 04m53s:_am_onScreenAction SCREEN_MATCHING
# 05m12s:_am_onScreenAction SCREEN_NO_MATCH
# 05m28s:_am_onScreenAction SCREEN_MATCHING
# 05m46s:_am_onScreenAction SCREEN_NO_MATCH
# 06m00s:_am_onScreenAction SCREEN_MATCHING
# 06m20s:_am_onScreenAction SCREEN_NO_MATCH
# 06m34s:_am_onScreenAction SCREEN_MATCHING
# 06m52s:_am_onScreenAction SCREEN_NO_MATCH
# 07m07s:_am_onScreenAction SCREEN_MATCHING
# 07m27s:_am_onScreenAction SCREEN_NO_MATCH
# 07m42s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 08m09s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 08m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 09m00s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 09m25s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 09m51s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# 10m16s:_am_onScreenAction SCREEN_MATCHING
# 10m34s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 江南
#  trackY: 江南
#  artist: 喻越越/杨鸿年少年合唱团
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [069: cnn-07_3117_20180718003124.wav_sub_3213_3393.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 01m00s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 01m25s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 01m49s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 02m14s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 02m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [070: cnn-07_3117_20180718003124.wav_sub_690_912.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 00m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# 00m54s:_am_onScreenAction SCREEN_MATCHING
# 01m12s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# 01m37s:_am_onScreenAction SCREEN_MATCHING
# 01m58s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# 02m26s:_am_onScreenAction SCREEN_MATCHING
# 02m46s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# 03m16s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# 03m42s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 木雅锅庄
#  trackY: 木雅锅庄
#  artist: 巴女母
# wav playing ends, exit androidManipulation()
#
# ====================
# [071: cnn-07_3118_20180718011101.wav_sub_948_1128.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m23s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 00m47s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 01m12s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 01m36s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 02m00s:_am_onScreenAction SCREEN_MATCHING
# 02m19s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# 02m44s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: 向往
#  trackY: 向往
#  artist: 廖昌永
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
#
# ====================
# [072: cnn-07_3121_20180718041101.wav_sub_2073_2253.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize _wp_run()...
# ('1200', '1920')
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# 00m47s:_am_onScreenAction SCREEN_MATCHING
# 01m09s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# 01m35s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# 02m01s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# 02m28s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# 02m54s:_am_onScreenAction _wp_deInit()...
# ['SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX: 莫斯科郊外的晚上
#  trackY: 莫斯科郊外的晚上
#  artist:
# wav playing ends, exit androidManipulation()
#
# ====================
# [073: cnn-07_3124_20180718071101.wav_sub_1206_1368.wav]
# _wp_init()...
# 00m00s:_am_getScreenSize ('1200', '1920')
# _wp_run()...
# 00m04s:_am_launchApp
# 00m04s:_am_onScreenAction SCREEN_MATCHING
# 00m22s:_am_onScreenAction SCREEN_NO_MATCH
# 00m38s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Deux Polonaises, S. 223 - II. Polonaise in E Major
#  trackY: Deux Polonaises, S. 223 - II. Polonaise in E Major
#  artist: Leslie Howard
# 01m03s:_am_onScreenAction SCREEN_MATCHING
# 01m23s:_am_onScreenAction SCREEN_ERROR_OCCUR
# 01m43s:_am_onScreenAction SCREEN_MATCHING
# 02m03s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_DONE']
#  trackX: Deux Polonaises, S. 223 - II. Polonaise in E Major
#  trackY: Deux Polonaises, S. 223 - II. Polonaise in E Major
#  artist: Leslie Howard
# 02m29s:_am_onScreenAction ['SCREEN_MATCHUP_EXTRACT_TRACK_NORMAL_FAIL', 'SCREEN_MATCHUP_EXTRACT_TRACK_PSM7_FAIL', 'SCREEN_MATCHUP_EXTRACT_ARTIST_FAIL']
#  trackX:
#  trackY:
#  artist:
# _wp_deInit()...
# wav playing ends, exit androidManipulation()
